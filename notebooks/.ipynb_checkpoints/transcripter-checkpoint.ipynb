# %% [markdown]
# # Environment setup

# %%
from openai import OpenAI
import os
import re
import pandas as pd
from dotenv import load_dotenv
import requests

# %%
import subprocess
import base64
from IPython.display import display, Image
import json
import math

# %%
# Parent directory of the current directory
path = os.path.dirname(os.getcwd()) 

# Paths to the folders of example images and transcriptions
image_folder = path+'/data/Archives_LLN_Nivelles_I_1921_REG 5193'
text_folder = path+'/data/transcriptions'

# %%
load_dotenv()
# Out:
# True

# %%
openai_API_KEY = os.getenv("OPENAI_API_KEY")
openai_client = OpenAI(api_key=openai_API_KEY)

# %% [markdown]
# # Few shot trials (Doesn't work well -- but don't think it is relevant.)

# %%
def handle_nan(obj):
    return {k: (None if (isinstance(v, float) and math.isnan(v)) else v) for k, v in obj.items()}


# Example Transcription Data
def read_json_files(folder_path):
    json_data_list = []

    # Process each JSON file in the folder
    for file_name in os.listdir(folder_path):
        if file_name.endswith('.json'):
            file_path = os.path.join(folder_path, file_name)
            
            # Read JSON data from file
            with open(file_path, 'r', encoding='utf-8') as json_file:
                json_data_pre = json.load(json_file, object_hook=handle_nan)
                json_data =json.dumps(json_data_pre, indent=4, ensure_ascii=False)
                json_data_list.append(json_data)

    return json_data_list

# Folder containing the JSON files
json_folder = os.path.join(path, 'data/json_transcriptions')

# Read all JSON files from the folder
all_json_data = read_json_files(json_folder)

# Print out the loaded JSON data (for demonstration purposes)
for idx, json_data in enumerate(all_json_data):
    print(f"Data from JSON file {idx + 1}:")
    print(json_data)
    print("\n")
# Out:
# Data from JSON file 1:
# [
#     {
#         "N' d'ordre": {
#             "Unnamed: 0_level_1": null
#         },
#         "Date du dépot des déclarations": {
#             "Unnamed: 1_level_1": 1921
#         },
#         "Désignation des personnes décédées ou absentes.": {
#             "Nom.": null,
#             "Prénoms": null,
#             "Domiciles": null,
#             "Domiciles.1": null
#         },
#         "Date du décès ous du judgement d'envoi en possession, en cas d'absence.": {
#             "Unnamed: 6_level_1": null
#         },
#         "Noms, Prénoms et demeures des parties déclarantes.": {
#             "Unnamed: 7_level_1": null
#         },
#         "Droits de succession en ligne collatérale et de mutation en ligne directe.": {
#             "Actif. (2)": null,
#             "Passif. (2)": null,
#             "Restant NET. (2)": null
#         },
#         "Droit de mutation par déces": {
#             "Valeur des immeubles. (2)": null
#         },
#         "Numéros des déclarations": {
#             "Primitives.": null,
#             "Supplémentaires.": null
#         },
#         "Date": {
#             "de l'expiration du délai de rectification.": null,
#             "de l'exigibilité des droits.": null
#         },
#         "Numéros de la consignation des droits au sommier n' 28": {
#             "Unnamed: 16_level_1": null
#         },
#         "Recette des droits et amendes.": {
#             "Date": null,
#             "N^03": null
#         },
#         "Cautionnements. ": {
#             "Numéros de la consignation au sommier n'30": null
#         },
#         "Observations": {
#             "(les déclarations qui figurent à l'état n'413 doivent être émargées en conséquence, dans la présnete colonne.)": null
#         }
#     },
#     {
#         "N' d'ordre": {
#             "Unnamed: 0_level_1": 150
#         },
#         "Date du dépot des déclarations": {
#             "Unnamed: 1_level_1": "vingt quatre juin"
#         },
#         "Désignation des personnes décédées ou absentes.": {
#             "Nom.": "Lambert",
#             "Prénoms": "Valentin",
#             "Domiciles": "Nivelles",
#             "Domiciles.1": null
#         },
#         "Date du décès ous du judgement d'envoi en possession, en cas d'absence.": {
#             "Unnamed: 6_level_1": "16 mars 1921"
#         },
#         "Noms, Prénoms et demeures des parties déclarantes.": {
#             "Unnamed: 7_level_1": "Greis Aurelie & autres"
#         },
#         "Droits de succession en ligne collatérale et de mutation en ligne directe.": {
#             "Actif. (2)": 18150.0,
#             "Passif. (2)": 1405.0,
#             "Restant NET. (2)": 16745.0
#         },
#         "Droit de mutation par déces": {
#             "Valeur des immeubles. (2)": null
#         },
#         "Numéros des déclarations": {
#             "Primitives.": null,
#             "Supplémentaires.": null
#         },
#         "Date": {
#             "de l'expiration du délai de rectification.": null,
#             "de l'exigibilité des droits.": null
#         },
#         "Numéros de la consignation des droits au sommier n' 28": {
#             "Unnamed: 16_level_1": null
#         },
#         "Recette des droits et amendes.": {
#             "Date": "16 mars 1922",
#             "N^03": 19.0
#         },
#         "Cautionnements. ": {
#             "Numéros de la consignation au sommier n'30": null
#         },
#         "Observations": {
#             "(les déclarations qui figurent à l'état n'413 doivent être émargées en conséquence, dans la présnete colonne.)": null
#         }
#     },
#     {
#         "N' d'ordre": {
#             "Unnamed: 0_level_1": 151
#         },
#         "Date du dépot des déclarations": {
#             "Unnamed: 1_level_1": "d"
#         },
#         "Désignation des personnes décédées ou absentes.": {
#             "Nom.": "Leveau",
#             "Prénoms": "Adolphine",
#             "Domiciles": "Clabecq",
#             "Domiciles.1": null
#         },
#         "Date du décès ous du judgement d'envoi en possession, en cas d'absence.": {
#             "Unnamed: 6_level_1": "8 mars 1919"
#         },
#         "Noms, Prénoms et demeures des parties déclarantes.": {
#             "Unnamed: 7_level_1": "Vanpée Ernest & autres"
#         },
#         "Droits de succession en ligne collatérale et de mutation en ligne directe.": {
#             "Actif. (2)": 4840.0,
#             "Passif. (2)": null,
#             "Restant NET. (2)": 4840.0
#         },
#         "Droit de mutation par déces": {
#             "Valeur des immeubles. (2)": null
#         },
#         "Numéros des déclarations": {
#             "Primitives.": null,
#             "Supplémentaires.": null
#         },
#         "Date": {
#             "de l'expiration du délai de rectification.": null,
#             "de l'exigibilité des droits.": null
#         },
#         "Numéros de la consignation des droits au sommier n' 28": {
#             "Unnamed: 16_level_1": null
#         },
#         "Recette des droits et amendes.": {
#             "Date": "4 octobre 1921",
#             "N^03": 189.0
#         },
#         "Cautionnements. ": {
#             "Numéros de la consignation au sommier n'30": null
#         },
#         "Observations": {
#             "(les déclarations qui figurent à l'état n'413 doivent être émargées en conséquence, dans la présnete colonne.)": null
#         }
#     },
#     {
#         "N' d'ordre": {
#             "Unnamed: 0_level_1": null
#         },
#         "Date du dépot des déclarations": {
#             "Unnamed: 1_level_1": null
#         },
#         "Désignation des personnes décédées ou absentes.": {
#             "Nom.": null,
#             "Prénoms": null,
#             "Domiciles": null,
#             "Domiciles.1": null
#         },
#         "Date du décès ous du judgement d'envoi en possession, en cas d'absence.": {
#             "Unnamed: 6_level_1": null
#         },
#         "Noms, Prénoms et demeures des parties déclarantes.": {
#             "Unnamed: 7_level_1": null
#         },
#         "Droits de succession en ligne collatérale et de mutation en ligne directe.": {
#             "Actif. (2)": null,
#             "Passif. (2)": null,
#             "Restant NET. (2)": null
#         },
#         "Droit de mutation par déces": {
#             "Valeur des immeubles. (2)": null
#         },
#         "Numéros des déclarations": {
#             "Primitives.": null,
#             "Supplémentaires.": null
#         },
#         "Date": {
#             "de l'expiration du délai de rectification.": null,
#             "de l'exigibilité des droits.": null
#         },
#         "Numéros de la consignation des droits au sommier n' 28": {
#             "Unnamed: 16_level_1": null
#         },
#         "Recette des droits et amendes.": {
#             "Date": "16 - ",
#             "N^03": 199.0
#         },
#         "Cautionnements. ": {
#             "Numéros de la consignation au sommier n'30": null
#         },
#         "Observations": {
#             "(les déclarations qui figurent à l'état n'413 doivent être émargées en conséquence, dans la présnete colonne.)": null
#         }
#     },
#     {
#         "N' d'ordre": {
#             "Unnamed: 0_level_1": 152
#         },
#         "Date du dépot des déclarations": {
#             "Unnamed: 1_level_1": "d"
#         },
#         "Désignation des personnes décédées ou absentes.": {
#             "Nom.": "Vanpée",
#             "Prénoms": "Frédéric",
#             "Domiciles": "d",
#             "Domiciles.1": null
#         },
#         "Date du décès ous du judgement d'envoi en possession, en cas d'absence.": {
#             "Unnamed: 6_level_1": "29 décembre 1920"
#         },
#         "Noms, Prénoms et demeures des parties déclarantes.": {
#             "Unnamed: 7_level_1": "d"
#         },
#         "Droits de succession en ligne collatérale et de mutation en ligne directe.": {
#             "Actif. (2)": 7122.0,
#             "Passif. (2)": 594.0,
#             "Restant NET. (2)": 6528.0
#         },
#         "Droit de mutation par déces": {
#             "Valeur des immeubles. (2)": null
#         },
#         "Numéros des déclarations": {
#             "Primitives.": null,
#             "Supplémentaires.": null
#         },
#         "Date": {
#             "de l'expiration du délai de rectification.": null,
#             "de l'exigibilité des droits.": null
#         },
#         "Numéros de la consignation des droits au sommier n' 28": {
#             "Unnamed: 16_level_1": null
#         },
#         "Recette des droits et amendes.": {
#             "Date": "non passible",
#             "N^03": null
#         },
#         "Cautionnements. ": {
#             "Numéros de la consignation au sommier n'30": null
#         },
#         "Observations": {
#             "(les déclarations qui figurent à l'état n'413 doivent être émargées en conséquence, dans la présnete colonne.)": null
#         }
#     },
#     {
#         "N' d'ordre": {
#             "Unnamed: 0_level_1": 153
#         },
#         "Date du dépot des déclarations": {
#             "Unnamed: 1_level_1": "d"
#         },
#         "Désignation des personnes décédées ou absentes.": {
#             "Nom.": "Delabij",
#             "Prénoms": "Joachim Joseph",
#             "Domiciles": "Wauthier-Braine",
#             "Domiciles.1": null
#         },
#         "Date du décès ous du judgement d'envoi en possession, en cas d'absence.": {
#             "Unnamed: 6_level_1": "24 janvier 1920"
#         },
#         "Noms, Prénoms et demeures des parties déclarantes.": {
#             "Unnamed: 7_level_1": "Jus.. Rosenè Marie"
#         },
#         "Droits de succession en ligne collatérale et de mutation en ligne directe.": {
#             "Actif. (2)": 2250.0,
#             "Passif. (2)": 526.0,
#             "Restant NET. (2)": 1723.0
#         },
#         "Droit de mutation par déces": {
#             "Valeur des immeubles. (2)": null
#         },
#         "Numéros des déclarations": {
#             "Primitives.": null,
#             "Supplémentaires.": null
#         },
#         "Date": {
#             "de l'expiration du délai de rectification.": null,
#             "de l'exigibilité des droits.": null
#         },
#         "Numéros de la consignation des droits au sommier n' 28": {
#             "Unnamed: 16_level_1": null
#         },
#         "Recette des droits et amendes.": {
#             "Date": "non passible",
#             "N^03": null
#         },
#         "Cautionnements. ": {
#             "Numéros de la consignation au sommier n'30": null
#         },
#         "Observations": {
#             "(les déclarations qui figurent à l'état n'413 doivent être émargées en conséquence, dans la présnete colonne.)": null
#         }
#     },
#     {
#         "N' d'ordre": {
#             "Unnamed: 0_level_1": null
#         },
#         "Date du dépot des déclarations": {
#             "Unnamed: 1_level_1": null
#         },
#         "Désignation des personnes décédées ou absentes.": {
#             "Nom.": "Arrété le vingt quatre juin 1921 ",
#             "Prénoms": null,
#             "Domiciles": null,
#             "Domiciles.1": "servais"
#         },
#         "Date du décès ous du judgement d'envoi en possession, en cas d'absence.": {
#             "Unnamed: 6_level_1": null
#         },
#         "Noms, Prénoms et demeures des parties déclarantes.": {
#             "Unnamed: 7_level_1": null
#         },
#         "Droits de succession en ligne collatérale et de mutation en ligne directe.": {
#             "Actif. (2)": null,
#             "Passif. (2)": null,
#             "Restant NET. (2)": null
#         },
#         "Droit de mutation par déces": {
#             "Valeur des immeubles. (2)": null
#         },
#         "Numéros des déclarations": {
#             "Primitives.": null,
#             "Supplémentaires.": null
#         },
#         "Date": {
#             "de l'expiration du délai de rectification.": null,
#             "de l'exigibilité des droits.": null
#         },
#         "Numéros de la consignation des droits au sommier n' 28": {
#             "Unnamed: 16_level_1": null
#         },
#         "Recette des droits et amendes.": {
#             "Date": null,
#             "N^03": null
#         },
#         "Cautionnements. ": {
#             "Numéros de la consignation au sommier n'30": null
#         },
#         "Observations": {
#             "(les déclarations qui figurent à l'état n'413 doivent être émargées en conséquence, dans la présnete colonne.)": null
#         }
#     },
#     {
#         "N' d'ordre": {
#             "Unnamed: 0_level_1": "153(2)"
#         },
#         "Date du dépot des déclarations": {
#             "Unnamed: 1_level_1": "vingt cinq juin"
#         },
#         "Désignation des personnes décédées ou absentes.": {
#             "Nom.": "Charlier",
#             "Prénoms": "Hortense",
#             "Domiciles": "Nivelles",
#             "Domiciles.1": null
#         },
#         "Date du décès ous du judgement d'envoi en possession, en cas d'absence.": {
#             "Unnamed: 6_level_1": null
#         },
#         "Noms, Prénoms et demeures des parties déclarantes.": {
#             "Unnamed: 7_level_1": "Huet Jules & Léon"
#         },
#         "Droits de succession en ligne collatérale et de mutation en ligne directe.": {
#             "Actif. (2)": 321.0,
#             "Passif. (2)": null,
#             "Restant NET. (2)": null
#         },
#         "Droit de mutation par déces": {
#             "Valeur des immeubles. (2)": null
#         },
#         "Numéros des déclarations": {
#             "Primitives.": "236/1920",
#             "Supplémentaires.": null
#         },
#         "Date": {
#             "de l'expiration du délai de rectification.": null,
#             "de l'exigibilité des droits.": null
#         },
#         "Numéros de la consignation des droits au sommier n' 28": {
#             "Unnamed: 16_level_1": null
#         },
#         "Recette des droits et amendes.": {
#             "Date": null,
#             "N^03": null
#         },
#         "Cautionnements. ": {
#             "Numéros de la consignation au sommier n'30": null
#         },
#         "Observations": {
#             "(les déclarations qui figurent à l'état n'413 doivent être émargées en conséquence, dans la présnete colonne.)": null
#         }
#     },
#     {
#         "N' d'ordre": {
#             "Unnamed: 0_level_1": null
#         },
#         "Date du dépot des déclarations": {
#             "Unnamed: 1_level_1": null
#         },
#         "Désignation des personnes décédées ou absentes.": {
#             "Nom.": "Arrété le vingt cinq juin 1921",
#             "Prénoms": null,
#             "Domiciles": null,
#             "Domiciles.1": "servais"
#         },
#         "Date du décès ous du judgement d'envoi en possession, en cas d'absence.": {
#             "Unnamed: 6_level_1": null
#         },
#         "Noms, Prénoms et demeures des parties déclarantes.": {
#             "Unnamed: 7_level_1": null
#         },
#         "Droits de succession en ligne collatérale et de mutation en ligne directe.": {
#             "Actif. (2)": null,
#             "Passif. (2)": null,
#             "Restant NET. (2)": null
#         },
#         "Droit de mutation par déces": {
#             "Valeur des immeubles. (2)": null
#         },
#         "Numéros des déclarations": {
#             "Primitives.": null,
#             "Supplémentaires.": null
#         },
#         "Date": {
#             "de l'expiration du délai de rectification.": null,
#             "de l'exigibilité des droits.": null
#         },
#         "Numéros de la consignation des droits au sommier n' 28": {
#             "Unnamed: 16_level_1": null
#         },
#         "Recette des droits et amendes.": {
#             "Date": null,
#             "N^03": null
#         },
#         "Cautionnements. ": {
#             "Numéros de la consignation au sommier n'30": null
#         },
#         "Observations": {
#             "(les déclarations qui figurent à l'état n'413 doivent être émargées en conséquence, dans la présnete colonne.)": null
#         }
#     },
#     {
#         "N' d'ordre": {
#             "Unnamed: 0_level_1": null
#         },
#         "Date du dépot des déclarations": {
#             "Unnamed: 1_level_1": null
#         },
#         "Désignation des personnes décédées ou absentes.": {
#             "Nom.": "Arrété le vingt six juin 1921 dimanche servais",
#             "Prénoms": null,
#             "Domiciles": null,
#             "Domiciles.1": null
#         },
#         "Date du décès ous du judgement d'envoi en possession, en cas d'absence.": {
#             "Unnamed: 6_level_1": null
#         },
#         "Noms, Prénoms et demeures des parties déclarantes.": {
#             "Unnamed: 7_level_1": null
#         },
#         "Droits de succession en ligne collatérale et de mutation en ligne directe.": {
#             "Actif. (2)": null,
#             "Passif. (2)": null,
#             "Restant NET. (2)": null
#         },
#         "Droit de mutation par déces": {
#             "Valeur des immeubles. (2)": null
#         },
#         "Numéros des déclarations": {
#             "Primitives.": null,
#             "Supplémentaires.": null
#         },
#         "Date": {
#             "de l'expiration du délai de rectification.": null,
#             "de l'exigibilité des droits.": null
#         },
#         "Numéros de la consignation des droits au sommier n' 28": {
#             "Unnamed: 16_level_1": null
#         },
#         "Recette des droits et amendes.": {
#             "Date": null,
#             "N^03": null
#         },
#         "Cautionnements. ": {
#             "Numéros de la consignation au sommier n'30": null
#         },
#         "Observations": {
#             "(les déclarations qui figurent à l'état n'413 doivent être émargées en conséquence, dans la présnete colonne.)": null
#         }
#     },
#     {
#         "N' d'ordre": {
#             "Unnamed: 0_level_1": 154
#         },
#         "Date du dépot des déclarations": {
#             "Unnamed: 1_level_1": "vingt sept"
#         },
#         "Désignation des personnes décédées ou absentes.": {
#             "Nom.": "Froment",
#             "Prénoms": "Georges ",
#             "Domiciles": "Nivelles",
#             "Domiciles.1": null
#         },
#         "Date du décès ous du judgement d'envoi en possession, en cas d'absence.": {
#             "Unnamed: 6_level_1": "28 décembre 1921"
#         },
#         "Noms, Prénoms et demeures des parties déclarantes.": {
#             "Unnamed: 7_level_1": "Vandromme Juliette"
#         },
#         "Droits de succession en ligne collatérale et de mutation en ligne directe.": {
#             "Actif. (2)": 150723.0,
#             "Passif. (2)": 5369.0,
#             "Restant NET. (2)": 145354.0
#         },
#         "Droit de mutation par déces": {
#             "Valeur des immeubles. (2)": null
#         },
#         "Numéros des déclarations": {
#             "Primitives.": "341(3)/1921",
#             "Supplémentaires.": null
#         },
#         "Date": {
#             "de l'expiration du délai de rectification.": null,
#             "de l'exigibilité des droits.": null
#         },
#         "Numéros de la consignation des droits au sommier n' 28": {
#             "Unnamed: 16_level_1": null
#         },
#         "Recette des droits et amendes.": {
#             "Date": "9 janvier 1922",
#             "N^03": 289.0
#         },
#         "Cautionnements. ": {
#             "Numéros de la consignation au sommier n'30": null
#         },
#         "Observations": {
#             "(les déclarations qui figurent à l'état n'413 doivent être émargées en conséquence, dans la présnete colonne.)": null
#         }
#     },
#     {
#         "N' d'ordre": {
#             "Unnamed: 0_level_1": 155
#         },
#         "Date du dépot des déclarations": {
#             "Unnamed: 1_level_1": "d"
#         },
#         "Désignation des personnes décédées ou absentes.": {
#             "Nom.": "Devreux",
#             "Prénoms": "Jean gte",
#             "Domiciles": "Braine Le Château",
#             "Domiciles.1": null
#         },
#         "Date du décès ous du judgement d'envoi en possession, en cas d'absence.": {
#             "Unnamed: 6_level_1": "31 janvier 1920"
#         },
#         "Noms, Prénoms et demeures des parties déclarantes.": {
#             "Unnamed: 7_level_1": "….. & autres"
#         },
#         "Droits de succession en ligne collatérale et de mutation en ligne directe.": {
#             "Actif. (2)": 2465.0,
#             "Passif. (2)": null,
#             "Restant NET. (2)": 2465.0
#         },
#         "Droit de mutation par déces": {
#             "Valeur des immeubles. (2)": null
#         },
#         "Numéros des déclarations": {
#             "Primitives.": null,
#             "Supplémentaires.": null
#         },
#         "Date": {
#             "de l'expiration du délai de rectification.": null,
#             "de l'exigibilité des droits.": null
#         },
#         "Numéros de la consignation des droits au sommier n' 28": {
#             "Unnamed: 16_level_1": null
#         },
#         "Recette des droits et amendes.": {
#             "Date": "non passible",
#             "N^03": null
#         },
#         "Cautionnements. ": {
#             "Numéros de la consignation au sommier n'30": null
#         },
#         "Observations": {
#             "(les déclarations qui figurent à l'état n'413 doivent être émargées en conséquence, dans la présnete colonne.)": null
#         }
#     },
#     {
#         "N' d'ordre": {
#             "Unnamed: 0_level_1": 156
#         },
#         "Date du dépot des déclarations": {
#             "Unnamed: 1_level_1": "d"
#         },
#         "Désignation des personnes décédées ou absentes.": {
#             "Nom.": "Scolas",
#             "Prénoms": "Jean Joseph",
#             "Domiciles": "Wauthier-Braine",
#             "Domiciles.1": null
#         },
#         "Date du décès ous du judgement d'envoi en possession, en cas d'absence.": {
#             "Unnamed: 6_level_1": "6 septembre 1920"
#         },
#         "Noms, Prénoms et demeures des parties déclarantes.": {
#             "Unnamed: 7_level_1": "Scolas Jules Jh & autres"
#         },
#         "Droits de succession en ligne collatérale et de mutation en ligne directe.": {
#             "Actif. (2)": 2485.0,
#             "Passif. (2)": null,
#             "Restant NET. (2)": 2485.0
#         },
#         "Droit de mutation par déces": {
#             "Valeur des immeubles. (2)": null
#         },
#         "Numéros des déclarations": {
#             "Primitives.": null,
#             "Supplémentaires.": null
#         },
#         "Date": {
#             "de l'expiration du délai de rectification.": null,
#             "de l'exigibilité des droits.": null
#         },
#         "Numéros de la consignation des droits au sommier n' 28": {
#             "Unnamed: 16_level_1": null
#         },
#         "Recette des droits et amendes.": {
#             "Date": "id",
#             "N^03": null
#         },
#         "Cautionnements. ": {
#             "Numéros de la consignation au sommier n'30": null
#         },
#         "Observations": {
#             "(les déclarations qui figurent à l'état n'413 doivent être émargées en conséquence, dans la présnete colonne.)": null
#         }
#     },
#     {
#         "N' d'ordre": {
#             "Unnamed: 0_level_1": null
#         },
#         "Date du dépot des déclarations": {
#             "Unnamed: 1_level_1": null
#         },
#         "Désignation des personnes décédées ou absentes.": {
#             "Nom.": "Arrété le vingt sept juin 1921 ",
#             "Prénoms": null,
#             "Domiciles": null,
#             "Domiciles.1": "servais"
#         },
#         "Date du décès ous du judgement d'envoi en possession, en cas d'absence.": {
#             "Unnamed: 6_level_1": null
#         },
#         "Noms, Prénoms et demeures des parties déclarantes.": {
#             "Unnamed: 7_level_1": null
#         },
#         "Droits de succession en ligne collatérale et de mutation en ligne directe.": {
#             "Actif. (2)": null,
#             "Passif. (2)": null,
#             "Restant NET. (2)": null
#         },
#         "Droit de mutation par déces": {
#             "Valeur des immeubles. (2)": null
#         },
#         "Numéros des déclarations": {
#             "Primitives.": null,
#             "Supplémentaires.": null
#         },
#         "Date": {
#             "de l'expiration du délai de rectification.": null,
#             "de l'exigibilité des droits.": null
#         },
#         "Numéros de la consignation des droits au sommier n' 28": {
#             "Unnamed: 16_level_1": null
#         },
#         "Recette des droits et amendes.": {
#             "Date": null,
#             "N^03": null
#         },
#         "Cautionnements. ": {
#             "Numéros de la consignation au sommier n'30": null
#         },
#         "Observations": {
#             "(les déclarations qui figurent à l'état n'413 doivent être émargées en conséquence, dans la présnete colonne.)": null
#         }
#     },
#     {
#         "N' d'ordre": {
#             "Unnamed: 0_level_1": 157
#         },
#         "Date du dépot des déclarations": {
#             "Unnamed: 1_level_1": "vingt huit"
#         },
#         "Désignation des personnes décédées ou absentes.": {
#             "Nom.": "Defalque",
#             "Prénoms": "Claria Emma",
#             "Domiciles": "Braine Le Château",
#             "Domiciles.1": null
#         },
#         "Date du décès ous du judgement d'envoi en possession, en cas d'absence.": {
#             "Unnamed: 6_level_1": "29 décembre 1920"
#         },
#         "Noms, Prénoms et demeures des parties déclarantes.": {
#             "Unnamed: 7_level_1": "Defalque Aueluide"
#         },
#         "Droits de succession en ligne collatérale et de mutation en ligne directe.": {
#             "Actif. (2)": 14245.0,
#             "Passif. (2)": 1326.0,
#             "Restant NET. (2)": 12919.0
#         },
#         "Droit de mutation par déces": {
#             "Valeur des immeubles. (2)": null
#         },
#         "Numéros des déclarations": {
#             "Primitives.": null,
#             "Supplémentaires.": null
#         },
#         "Date": {
#             "de l'expiration du délai de rectification.": null,
#             "de l'exigibilité des droits.": null
#         },
#         "Numéros de la consignation des droits au sommier n' 28": {
#             "Unnamed: 16_level_1": null
#         },
#         "Recette des droits et amendes.": {
#             "Date": "9 décmebre 1921",
#             "N^03": 298.0
#         },
#         "Cautionnements. ": {
#             "Numéros de la consignation au sommier n'30": null
#         },
#         "Observations": {
#             "(les déclarations qui figurent à l'état n'413 doivent être émargées en conséquence, dans la présnete colonne.)": null
#         }
#     }
# ]
#
#
# Data from JSON file 2:
# [
#     {
#         "N' d'ordre": {
#             "Unnamed: 0_level_1": null
#         },
#         "Date du dépot des déclarations": {
#             "Unnamed: 1_level_1": null
#         },
#         "Désignation des personnes décédées ou absentes.": {
#             "Nom.": "Arrêté le seize juin 1921",
#             "Prénoms": null,
#             "Domiciles": null,
#             "Domiciles.1": "servais"
#         },
#         "Date du décès ous du judgement d'envoi en possession, en cas d'absence.": {
#             "Unnamed: 6_level_1": null
#         },
#         "Noms, Prénoms et demeures des parties déclarantes.": {
#             "Unnamed: 7_level_1": null
#         },
#         "Droits de succession en ligne collatérale et de mutation en ligne directe.": {
#             "Actif. (2)": null,
#             "Passif. (2)": null,
#             "Restant NET. (2)": null
#         },
#         "Droit de mutation par déces": {
#             "Valeur des immeubles. (2)": null
#         },
#         "Numéros des déclarations": {
#             "Primitives.": null,
#             "Supplémentaires.": null
#         },
#         "Date": {
#             "de l'expiration du délai de rectification.": null,
#             "de l'exigibilité des droits.": null
#         },
#         "Numéros de la consignation des droits au sommier n' 28": {
#             "Unnamed: 16_level_1": null
#         },
#         "Recette des droits et amendes.": {
#             "Date": null,
#             "N^03": null
#         },
#         "Cautionnements. ": {
#             "Numéros de la consignation au sommier n'30": null
#         },
#         "Observations": {
#             "(les déclarations qui figurent à l'état n'413 doivent être émargées en conséquence, dans la présnete colonne.)": null
#         }
#     },
#     {
#         "N' d'ordre": {
#             "Unnamed: 0_level_1": 145.0
#         },
#         "Date du dépot des déclarations": {
#             "Unnamed: 1_level_1": "dix sept juin"
#         },
#         "Désignation des personnes décédées ou absentes.": {
#             "Nom.": "Luyex",
#             "Prénoms": "Charles Louis",
#             "Domiciles": "Virginal",
#             "Domiciles.1": null
#         },
#         "Date du décès ous du judgement d'envoi en possession, en cas d'absence.": {
#             "Unnamed: 6_level_1": "16 novembre 1920"
#         },
#         "Noms, Prénoms et demeures des parties déclarantes.": {
#             "Unnamed: 7_level_1": "Van … Julienne & autres"
#         },
#         "Droits de succession en ligne collatérale et de mutation en ligne directe.": {
#             "Actif. (2)": 54845.0,
#             "Passif. (2)": 1413.0,
#             "Restant NET. (2)": 53432.0
#         },
#         "Droit de mutation par déces": {
#             "Valeur des immeubles. (2)": null
#         },
#         "Numéros des déclarations": {
#             "Primitives.": null,
#             "Supplémentaires.": null
#         },
#         "Date": {
#             "de l'expiration du délai de rectification.": null,
#             "de l'exigibilité des droits.": null
#         },
#         "Numéros de la consignation des droits au sommier n' 28": {
#             "Unnamed: 16_level_1": null
#         },
#         "Recette des droits et amendes.": {
#             "Date": "28 novembre 1921",
#             "N^03": 174.0
#         },
#         "Cautionnements. ": {
#             "Numéros de la consignation au sommier n'30": null
#         },
#         "Observations": {
#             "(les déclarations qui figurent à l'état n'413 doivent être émargées en conséquence, dans la présnete colonne.)": null
#         }
#     },
#     {
#         "N' d'ordre": {
#             "Unnamed: 0_level_1": null
#         },
#         "Date du dépot des déclarations": {
#             "Unnamed: 1_level_1": null
#         },
#         "Désignation des personnes décédées ou absentes.": {
#             "Nom.": null,
#             "Prénoms": null,
#             "Domiciles": null,
#             "Domiciles.1": null
#         },
#         "Date du décès ous du judgement d'envoi en possession, en cas d'absence.": {
#             "Unnamed: 6_level_1": null
#         },
#         "Noms, Prénoms et demeures des parties déclarantes.": {
#             "Unnamed: 7_level_1": null
#         },
#         "Droits de succession en ligne collatérale et de mutation en ligne directe.": {
#             "Actif. (2)": null,
#             "Passif. (2)": null,
#             "Restant NET. (2)": null
#         },
#         "Droit de mutation par déces": {
#             "Valeur des immeubles. (2)": null
#         },
#         "Numéros des déclarations": {
#             "Primitives.": null,
#             "Supplémentaires.": null
#         },
#         "Date": {
#             "de l'expiration du délai de rectification.": null,
#             "de l'exigibilité des droits.": null
#         },
#         "Numéros de la consignation des droits au sommier n' 28": {
#             "Unnamed: 16_level_1": null
#         },
#         "Recette des droits et amendes.": {
#             "Date": "16 septembre 1921",
#             "N^03": 391.0
#         },
#         "Cautionnements. ": {
#             "Numéros de la consignation au sommier n'30": null
#         },
#         "Observations": {
#             "(les déclarations qui figurent à l'état n'413 doivent être émargées en conséquence, dans la présnete colonne.)": null
#         }
#     },
#     {
#         "N' d'ordre": {
#             "Unnamed: 0_level_1": null
#         },
#         "Date du dépot des déclarations": {
#             "Unnamed: 1_level_1": null
#         },
#         "Désignation des personnes décédées ou absentes.": {
#             "Nom.": "Arrêté le dix sept juin 1921 servais",
#             "Prénoms": null,
#             "Domiciles": null,
#             "Domiciles.1": "servais"
#         },
#         "Date du décès ous du judgement d'envoi en possession, en cas d'absence.": {
#             "Unnamed: 6_level_1": null
#         },
#         "Noms, Prénoms et demeures des parties déclarantes.": {
#             "Unnamed: 7_level_1": null
#         },
#         "Droits de succession en ligne collatérale et de mutation en ligne directe.": {
#             "Actif. (2)": null,
#             "Passif. (2)": null,
#             "Restant NET. (2)": null
#         },
#         "Droit de mutation par déces": {
#             "Valeur des immeubles. (2)": null
#         },
#         "Numéros des déclarations": {
#             "Primitives.": null,
#             "Supplémentaires.": null
#         },
#         "Date": {
#             "de l'expiration du délai de rectification.": null,
#             "de l'exigibilité des droits.": null
#         },
#         "Numéros de la consignation des droits au sommier n' 28": {
#             "Unnamed: 16_level_1": null
#         },
#         "Recette des droits et amendes.": {
#             "Date": null,
#             "N^03": null
#         },
#         "Cautionnements. ": {
#             "Numéros de la consignation au sommier n'30": null
#         },
#         "Observations": {
#             "(les déclarations qui figurent à l'état n'413 doivent être émargées en conséquence, dans la présnete colonne.)": null
#         }
#     },
#     {
#         "N' d'ordre": {
#             "Unnamed: 0_level_1": 146.0
#         },
#         "Date du dépot des déclarations": {
#             "Unnamed: 1_level_1": "dix huit juin"
#         },
#         "Désignation des personnes décédées ou absentes.": {
#             "Nom.": "Masson",
#             "Prénoms": "Jean Bte",
#             "Domiciles": "Baulers",
#             "Domiciles.1": null
#         },
#         "Date du décès ous du judgement d'envoi en possession, en cas d'absence.": {
#             "Unnamed: 6_level_1": "19 décembre 1920"
#         },
#         "Noms, Prénoms et demeures des parties déclarantes.": {
#             "Unnamed: 7_level_1": "Rose Eloise"
#         },
#         "Droits de succession en ligne collatérale et de mutation en ligne directe.": {
#             "Actif. (2)": 12905.0,
#             "Passif. (2)": 854.0,
#             "Restant NET. (2)": 12020.0
#         },
#         "Droit de mutation par déces": {
#             "Valeur des immeubles. (2)": null
#         },
#         "Numéros des déclarations": {
#             "Primitives.": null,
#             "Supplémentaires.": null
#         },
#         "Date": {
#             "de l'expiration du délai de rectification.": null,
#             "de l'exigibilité des droits.": null
#         },
#         "Numéros de la consignation des droits au sommier n' 28": {
#             "Unnamed: 16_level_1": null
#         },
#         "Recette des droits et amendes.": {
#             "Date": "28 - 11 - 1921",
#             "N^03": 169.0
#         },
#         "Cautionnements. ": {
#             "Numéros de la consignation au sommier n'30": null
#         },
#         "Observations": {
#             "(les déclarations qui figurent à l'état n'413 doivent être émargées en conséquence, dans la présnete colonne.)": null
#         }
#     },
#     {
#         "N' d'ordre": {
#             "Unnamed: 0_level_1": null
#         },
#         "Date du dépot des déclarations": {
#             "Unnamed: 1_level_1": null
#         },
#         "Désignation des personnes décédées ou absentes.": {
#             "Nom.": "Arrêté le dix huit juin 1921",
#             "Prénoms": null,
#             "Domiciles": null,
#             "Domiciles.1": "servais"
#         },
#         "Date du décès ous du judgement d'envoi en possession, en cas d'absence.": {
#             "Unnamed: 6_level_1": null
#         },
#         "Noms, Prénoms et demeures des parties déclarantes.": {
#             "Unnamed: 7_level_1": null
#         },
#         "Droits de succession en ligne collatérale et de mutation en ligne directe.": {
#             "Actif. (2)": null,
#             "Passif. (2)": null,
#             "Restant NET. (2)": null
#         },
#         "Droit de mutation par déces": {
#             "Valeur des immeubles. (2)": null
#         },
#         "Numéros des déclarations": {
#             "Primitives.": null,
#             "Supplémentaires.": null
#         },
#         "Date": {
#             "de l'expiration du délai de rectification.": null,
#             "de l'exigibilité des droits.": null
#         },
#         "Numéros de la consignation des droits au sommier n' 28": {
#             "Unnamed: 16_level_1": null
#         },
#         "Recette des droits et amendes.": {
#             "Date": null,
#             "N^03": null
#         },
#         "Cautionnements. ": {
#             "Numéros de la consignation au sommier n'30": null
#         },
#         "Observations": {
#             "(les déclarations qui figurent à l'état n'413 doivent être émargées en conséquence, dans la présnete colonne.)": null
#         }
#     },
#     {
#         "N' d'ordre": {
#             "Unnamed: 0_level_1": null
#         },
#         "Date du dépot des déclarations": {
#             "Unnamed: 1_level_1": null
#         },
#         "Désignation des personnes décédées ou absentes.": {
#             "Nom.": "Arrêté le dix neuf juin 1921 Dimanche",
#             "Prénoms": null,
#             "Domiciles": null,
#             "Domiciles.1": "servais"
#         },
#         "Date du décès ous du judgement d'envoi en possession, en cas d'absence.": {
#             "Unnamed: 6_level_1": null
#         },
#         "Noms, Prénoms et demeures des parties déclarantes.": {
#             "Unnamed: 7_level_1": null
#         },
#         "Droits de succession en ligne collatérale et de mutation en ligne directe.": {
#             "Actif. (2)": null,
#             "Passif. (2)": null,
#             "Restant NET. (2)": null
#         },
#         "Droit de mutation par déces": {
#             "Valeur des immeubles. (2)": null
#         },
#         "Numéros des déclarations": {
#             "Primitives.": null,
#             "Supplémentaires.": null
#         },
#         "Date": {
#             "de l'expiration du délai de rectification.": null,
#             "de l'exigibilité des droits.": null
#         },
#         "Numéros de la consignation des droits au sommier n' 28": {
#             "Unnamed: 16_level_1": null
#         },
#         "Recette des droits et amendes.": {
#             "Date": null,
#             "N^03": null
#         },
#         "Cautionnements. ": {
#             "Numéros de la consignation au sommier n'30": null
#         },
#         "Observations": {
#             "(les déclarations qui figurent à l'état n'413 doivent être émargées en conséquence, dans la présnete colonne.)": null
#         }
#     },
#     {
#         "N' d'ordre": {
#             "Unnamed: 0_level_1": null
#         },
#         "Date du dépot des déclarations": {
#             "Unnamed: 1_level_1": null
#         },
#         "Désignation des personnes décédées ou absentes.": {
#             "Nom.": "Arrêté le vingt juin 1921 ",
#             "Prénoms": null,
#             "Domiciles": null,
#             "Domiciles.1": "servais"
#         },
#         "Date du décès ous du judgement d'envoi en possession, en cas d'absence.": {
#             "Unnamed: 6_level_1": null
#         },
#         "Noms, Prénoms et demeures des parties déclarantes.": {
#             "Unnamed: 7_level_1": null
#         },
#         "Droits de succession en ligne collatérale et de mutation en ligne directe.": {
#             "Actif. (2)": null,
#             "Passif. (2)": null,
#             "Restant NET. (2)": null
#         },
#         "Droit de mutation par déces": {
#             "Valeur des immeubles. (2)": null
#         },
#         "Numéros des déclarations": {
#             "Primitives.": null,
#             "Supplémentaires.": null
#         },
#         "Date": {
#             "de l'expiration du délai de rectification.": null,
#             "de l'exigibilité des droits.": null
#         },
#         "Numéros de la consignation des droits au sommier n' 28": {
#             "Unnamed: 16_level_1": null
#         },
#         "Recette des droits et amendes.": {
#             "Date": null,
#             "N^03": null
#         },
#         "Cautionnements. ": {
#             "Numéros de la consignation au sommier n'30": null
#         },
#         "Observations": {
#             "(les déclarations qui figurent à l'état n'413 doivent être émargées en conséquence, dans la présnete colonne.)": null
#         }
#     },
#     {
#         "N' d'ordre": {
#             "Unnamed: 0_level_1": 147.0
#         },
#         "Date du dépot des déclarations": {
#             "Unnamed: 1_level_1": "vingt un juin"
#         },
#         "Désignation des personnes décédées ou absentes.": {
#             "Nom.": "Leblicq",
#             "Prénoms": "Jean Bte",
#             "Domiciles": "Heneaoit",
#             "Domiciles.1": null
#         },
#         "Date du décès ous du judgement d'envoi en possession, en cas d'absence.": {
#             "Unnamed: 6_level_1": "13 mars 1920"
#         },
#         "Noms, Prénoms et demeures des parties déclarantes.": {
#             "Unnamed: 7_level_1": "Pierot Marie Obirèle & autres"
#         },
#         "Droits de succession en ligne collatérale et de mutation en ligne directe.": {
#             "Actif. (2)": 1960.0,
#             "Passif. (2)": 336.0,
#             "Restant NET. (2)": 1624.0
#         },
#         "Droit de mutation par déces": {
#             "Valeur des immeubles. (2)": null
#         },
#         "Numéros des déclarations": {
#             "Primitives.": null,
#             "Supplémentaires.": null
#         },
#         "Date": {
#             "de l'expiration du délai de rectification.": null,
#             "de l'exigibilité des droits.": null
#         },
#         "Numéros de la consignation des droits au sommier n' 28": {
#             "Unnamed: 16_level_1": null
#         },
#         "Recette des droits et amendes.": {
#             "Date": "non passible",
#             "N^03": null
#         },
#         "Cautionnements. ": {
#             "Numéros de la consignation au sommier n'30": null
#         },
#         "Observations": {
#             "(les déclarations qui figurent à l'état n'413 doivent être émargées en conséquence, dans la présnete colonne.)": null
#         }
#     },
#     {
#         "N' d'ordre": {
#             "Unnamed: 0_level_1": null
#         },
#         "Date du dépot des déclarations": {
#             "Unnamed: 1_level_1": null
#         },
#         "Désignation des personnes décédées ou absentes.": {
#             "Nom.": "Arrêté le vingt un juin 1921",
#             "Prénoms": null,
#             "Domiciles": null,
#             "Domiciles.1": "servais"
#         },
#         "Date du décès ous du judgement d'envoi en possession, en cas d'absence.": {
#             "Unnamed: 6_level_1": null
#         },
#         "Noms, Prénoms et demeures des parties déclarantes.": {
#             "Unnamed: 7_level_1": null
#         },
#         "Droits de succession en ligne collatérale et de mutation en ligne directe.": {
#             "Actif. (2)": null,
#             "Passif. (2)": null,
#             "Restant NET. (2)": null
#         },
#         "Droit de mutation par déces": {
#             "Valeur des immeubles. (2)": null
#         },
#         "Numéros des déclarations": {
#             "Primitives.": null,
#             "Supplémentaires.": null
#         },
#         "Date": {
#             "de l'expiration du délai de rectification.": null,
#             "de l'exigibilité des droits.": null
#         },
#         "Numéros de la consignation des droits au sommier n' 28": {
#             "Unnamed: 16_level_1": null
#         },
#         "Recette des droits et amendes.": {
#             "Date": null,
#             "N^03": null
#         },
#         "Cautionnements. ": {
#             "Numéros de la consignation au sommier n'30": null
#         },
#         "Observations": {
#             "(les déclarations qui figurent à l'état n'413 doivent être émargées en conséquence, dans la présnete colonne.)": null
#         }
#     },
#     {
#         "N' d'ordre": {
#             "Unnamed: 0_level_1": null
#         },
#         "Date du dépot des déclarations": {
#             "Unnamed: 1_level_1": null
#         },
#         "Désignation des personnes décédées ou absentes.": {
#             "Nom.": "Arrêté le vingt deux juin 1921",
#             "Prénoms": null,
#             "Domiciles": null,
#             "Domiciles.1": "servais"
#         },
#         "Date du décès ous du judgement d'envoi en possession, en cas d'absence.": {
#             "Unnamed: 6_level_1": null
#         },
#         "Noms, Prénoms et demeures des parties déclarantes.": {
#             "Unnamed: 7_level_1": null
#         },
#         "Droits de succession en ligne collatérale et de mutation en ligne directe.": {
#             "Actif. (2)": null,
#             "Passif. (2)": null,
#             "Restant NET. (2)": null
#         },
#         "Droit de mutation par déces": {
#             "Valeur des immeubles. (2)": null
#         },
#         "Numéros des déclarations": {
#             "Primitives.": null,
#             "Supplémentaires.": null
#         },
#         "Date": {
#             "de l'expiration du délai de rectification.": null,
#             "de l'exigibilité des droits.": null
#         },
#         "Numéros de la consignation des droits au sommier n' 28": {
#             "Unnamed: 16_level_1": null
#         },
#         "Recette des droits et amendes.": {
#             "Date": null,
#             "N^03": null
#         },
#         "Cautionnements. ": {
#             "Numéros de la consignation au sommier n'30": null
#         },
#         "Observations": {
#             "(les déclarations qui figurent à l'état n'413 doivent être émargées en conséquence, dans la présnete colonne.)": null
#         }
#     },
#     {
#         "N' d'ordre": {
#             "Unnamed: 0_level_1": null
#         },
#         "Date du dépot des déclarations": {
#             "Unnamed: 1_level_1": null
#         },
#         "Désignation des personnes décédées ou absentes.": {
#             "Nom.": "Arrêté le vingt trois juin 1921",
#             "Prénoms": null,
#             "Domiciles": null,
#             "Domiciles.1": "servais"
#         },
#         "Date du décès ous du judgement d'envoi en possession, en cas d'absence.": {
#             "Unnamed: 6_level_1": null
#         },
#         "Noms, Prénoms et demeures des parties déclarantes.": {
#             "Unnamed: 7_level_1": null
#         },
#         "Droits de succession en ligne collatérale et de mutation en ligne directe.": {
#             "Actif. (2)": null,
#             "Passif. (2)": null,
#             "Restant NET. (2)": null
#         },
#         "Droit de mutation par déces": {
#             "Valeur des immeubles. (2)": null
#         },
#         "Numéros des déclarations": {
#             "Primitives.": null,
#             "Supplémentaires.": null
#         },
#         "Date": {
#             "de l'expiration du délai de rectification.": null,
#             "de l'exigibilité des droits.": null
#         },
#         "Numéros de la consignation des droits au sommier n' 28": {
#             "Unnamed: 16_level_1": null
#         },
#         "Recette des droits et amendes.": {
#             "Date": null,
#             "N^03": null
#         },
#         "Cautionnements. ": {
#             "Numéros de la consignation au sommier n'30": null
#         },
#         "Observations": {
#             "(les déclarations qui figurent à l'état n'413 doivent être émargées en conséquence, dans la présnete colonne.)": null
#         }
#     },
#     {
#         "N' d'ordre": {
#             "Unnamed: 0_level_1": 148.0
#         },
#         "Date du dépot des déclarations": {
#             "Unnamed: 1_level_1": "vingt quatre"
#         },
#         "Désignation des personnes décédées ou absentes.": {
#             "Nom.": "Dasset",
#             "Prénoms": "Emmanuel Joseph",
#             "Domiciles": "Quenast",
#             "Domiciles.1": null
#         },
#         "Date du décès ous du judgement d'envoi en possession, en cas d'absence.": {
#             "Unnamed: 6_level_1": "30 juillet 1920"
#         },
#         "Noms, Prénoms et demeures des parties déclarantes.": {
#             "Unnamed: 7_level_1": "Giriss Emilie & autres"
#         },
#         "Droits de succession en ligne collatérale et de mutation en ligne directe.": {
#             "Actif. (2)": 2945.0,
#             "Passif. (2)": 1333.0,
#             "Restant NET. (2)": 1612.0
#         },
#         "Droit de mutation par déces": {
#             "Valeur des immeubles. (2)": null
#         },
#         "Numéros des déclarations": {
#             "Primitives.": null,
#             "Supplémentaires.": "260(5)/1922"
#         },
#         "Date": {
#             "de l'expiration du délai de rectification.": null,
#             "de l'exigibilité des droits.": null
#         },
#         "Numéros de la consignation des droits au sommier n' 28": {
#             "Unnamed: 16_level_1": null
#         },
#         "Recette des droits et amendes.": {
# ...
#             "N^03": null
#         },
#         "Cautionnements. ": {
#             "Numéros de la consignation au sommier n'30": null
#         },
#         "Observations": {
#             "(les déclarations qui figurent à l'état n'413 doivent être émargées en conséquence, dans la présnete colonne.)": null
#         }
#     },
#     {
#         "N' d'ordre": {
#             "Unnamed: 0_level_1": 423
#         },
#         "Date du dépot des déclarations": {
#             "Unnamed: 1_level_1": "d "
#         },
#         "Désignation des personnes décédées ou absentes.": {
#             "Nom.": "Desaeger",
#             "Prénoms": "Henri Marthe",
#             "Domiciles": "Rebcq",
#             "Domiciles.1": null
#         },
#         "Date du décès ous du judgement d'envoi en possession, en cas d'absence.": {
#             "Unnamed: 6_level_1": "26 mai 1919"
#         },
#         "Noms, Prénoms et demeures des parties déclarantes.": {
#             "Unnamed: 7_level_1": "Blondiau Vital"
#         },
#         "Droits de succession en ligne collatérale et de mutation en ligne directe.": {
#             "Actif. (2)": 2875,
#             "Passif. (2)": null,
#             "Restant NET. (2)": 2875.0
#         },
#         "Droit de mutation par déces": {
#             "Valeur des immeubles. (2)": null
#         },
#         "Numéros des déclarations": {
#             "Primitives.": null,
#             "Supplémentaires.": null
#         },
#         "Date": {
#             "de l'expiration du délai de rectification.": "31 d",
#             "de l'exigibilité des droits.": "26 d"
#         },
#         "Numéros de la consignation des droits au sommier n' 28": {
#             "Unnamed: 16_level_1": null
#         },
#         "Recette des droits et amendes.": {
#             "Date": "18 mars 1920",
#             "N^03": 60
#         },
#         "Cautionnements. ": {
#             "Numéros de la consignation au sommier n'30": null
#         },
#         "Observations": {
#             "(les déclarations qui figurent à l'état n'413 doivent être émargées en conséquence, dans la présnete colonne.)": null
#         }
#     },
#     {
#         "N' d'ordre": {
#             "Unnamed: 0_level_1": null
#         },
#         "Date du dépot des déclarations": {
#             "Unnamed: 1_level_1": null
#         },
#         "Désignation des personnes décédées ou absentes.": {
#             "Nom.": "Arreté le dix neuf novembre 1919",
#             "Prénoms": null,
#             "Domiciles": null,
#             "Domiciles.1": "servais"
#         },
#         "Date du décès ous du judgement d'envoi en possession, en cas d'absence.": {
#             "Unnamed: 6_level_1": null
#         },
#         "Noms, Prénoms et demeures des parties déclarantes.": {
#             "Unnamed: 7_level_1": null
#         },
#         "Droits de succession en ligne collatérale et de mutation en ligne directe.": {
#             "Actif. (2)": null,
#             "Passif. (2)": null,
#             "Restant NET. (2)": null
#         },
#         "Droit de mutation par déces": {
#             "Valeur des immeubles. (2)": null
#         },
#         "Numéros des déclarations": {
#             "Primitives.": null,
#             "Supplémentaires.": null
#         },
#         "Date": {
#             "de l'expiration du délai de rectification.": null,
#             "de l'exigibilité des droits.": null
#         },
#         "Numéros de la consignation des droits au sommier n' 28": {
#             "Unnamed: 16_level_1": null
#         },
#         "Recette des droits et amendes.": {
#             "Date": null,
#             "N^03": null
#         },
#         "Cautionnements. ": {
#             "Numéros de la consignation au sommier n'30": null
#         },
#         "Observations": {
#             "(les déclarations qui figurent à l'état n'413 doivent être émargées en conséquence, dans la présnete colonne.)": null
#         }
#     },
#     {
#         "N' d'ordre": {
#             "Unnamed: 0_level_1": 424
#         },
#         "Date du dépot des déclarations": {
#             "Unnamed: 1_level_1": "vingt 9bre"
#         },
#         "Désignation des personnes décédées ou absentes.": {
#             "Nom.": "Hautier",
#             "Prénoms": "Frèmin",
#             "Domiciles": "Nivelles",
#             "Domiciles.1": null
#         },
#         "Date du décès ous du judgement d'envoi en possession, en cas d'absence.": {
#             "Unnamed: 6_level_1": "23 juillet 1919"
#         },
#         "Noms, Prénoms et demeures des parties déclarantes.": {
#             "Unnamed: 7_level_1": "Lerus Juliette & autres"
#         },
#         "Droits de succession en ligne collatérale et de mutation en ligne directe.": {
#             "Actif. (2)": 86181,
#             "Passif. (2)": null,
#             "Restant NET. (2)": 86181.0
#         },
#         "Droit de mutation par déces": {
#             "Valeur des immeubles. (2)": null
#         },
#         "Numéros des déclarations": {
#             "Primitives.": null,
#             "Supplémentaires.": "372/1920"
#         },
#         "Date": {
#             "de l'expiration du délai de rectification.": "1 janvier 1920",
#             "de l'exigibilité des droits.": "23 mai 1920"
#         },
#         "Numéros de la consignation des droits au sommier n' 28": {
#             "Unnamed: 16_level_1": null
#         },
#         "Recette des droits et amendes.": {
#             "Date": "16 avril 1920",
#             "N^03": 83
#         },
#         "Cautionnements. ": {
#             "Numéros de la consignation au sommier n'30": null
#         },
#         "Observations": {
#             "(les déclarations qui figurent à l'état n'413 doivent être émargées en conséquence, dans la présnete colonne.)": null
#         }
#     },
#     {
#         "N' d'ordre": {
#             "Unnamed: 0_level_1": 425
#         },
#         "Date du dépot des déclarations": {
#             "Unnamed: 1_level_1": "d "
#         },
#         "Désignation des personnes décédées ou absentes.": {
#             "Nom.": "Delaitre",
#             "Prénoms": "Calien Cathérine gn",
#             "Domiciles": "Braine l'alleud",
#             "Domiciles.1": null
#         },
#         "Date du décès ous du judgement d'envoi en possession, en cas d'absence.": {
#             "Unnamed: 6_level_1": "26 mai 1919"
#         },
#         "Noms, Prénoms et demeures des parties déclarantes.": {
#             "Unnamed: 7_level_1": "Scouppe Jean Bte & autres"
#         },
#         "Droits de succession en ligne collatérale et de mutation en ligne directe.": {
#             "Actif. (2)": 1500,
#             "Passif. (2)": null,
#             "Restant NET. (2)": 1500.0
#         },
#         "Droit de mutation par déces": {
#             "Valeur des immeubles. (2)": null
#         },
#         "Numéros des déclarations": {
#             "Primitives.": null,
#             "Supplémentaires.": null
#         },
#         "Date": {
#             "de l'expiration du délai de rectification.": "1 d",
#             "de l'exigibilité des droits.": "26 mars 1920"
#         },
#         "Numéros de la consignation des droits au sommier n' 28": {
#             "Unnamed: 16_level_1": null
#         },
#         "Recette des droits et amendes.": {
#             "Date": "non passible",
#             "N^03": null
#         },
#         "Cautionnements. ": {
#             "Numéros de la consignation au sommier n'30": null
#         },
#         "Observations": {
#             "(les déclarations qui figurent à l'état n'413 doivent être émargées en conséquence, dans la présnete colonne.)": null
#         }
#     },
#     {
#         "N' d'ordre": {
#             "Unnamed: 0_level_1": null
#         },
#         "Date du dépot des déclarations": {
#             "Unnamed: 1_level_1": null
#         },
#         "Désignation des personnes décédées ou absentes.": {
#             "Nom.": "Arreté le vingt novembre 1919",
#             "Prénoms": null,
#             "Domiciles": null,
#             "Domiciles.1": "servais"
#         },
#         "Date du décès ous du judgement d'envoi en possession, en cas d'absence.": {
#             "Unnamed: 6_level_1": null
#         },
#         "Noms, Prénoms et demeures des parties déclarantes.": {
#             "Unnamed: 7_level_1": null
#         },
#         "Droits de succession en ligne collatérale et de mutation en ligne directe.": {
#             "Actif. (2)": null,
#             "Passif. (2)": null,
#             "Restant NET. (2)": null
#         },
#         "Droit de mutation par déces": {
#             "Valeur des immeubles. (2)": null
#         },
#         "Numéros des déclarations": {
#             "Primitives.": null,
#             "Supplémentaires.": null
#         },
#         "Date": {
#             "de l'expiration du délai de rectification.": null,
#             "de l'exigibilité des droits.": null
#         },
#         "Numéros de la consignation des droits au sommier n' 28": {
#             "Unnamed: 16_level_1": null
#         },
#         "Recette des droits et amendes.": {
#             "Date": null,
#             "N^03": null
#         },
#         "Cautionnements. ": {
#             "Numéros de la consignation au sommier n'30": null
#         },
#         "Observations": {
#             "(les déclarations qui figurent à l'état n'413 doivent être émargées en conséquence, dans la présnete colonne.)": null
#         }
#     },
#     {
#         "N' d'ordre": {
#             "Unnamed: 0_level_1": "425^2"
#         },
#         "Date du dépot des déclarations": {
#             "Unnamed: 1_level_1": "vingt un 9bre"
#         },
#         "Désignation des personnes décédées ou absentes.": {
#             "Nom.": "Piercot",
#             "Prénoms": "Julien",
#             "Domiciles": "Waterloo",
#             "Domiciles.1": null
#         },
#         "Date du décès ous du judgement d'envoi en possession, en cas d'absence.": {
#             "Unnamed: 6_level_1": "6 fevrier 1919"
#         },
#         "Noms, Prénoms et demeures des parties déclarantes.": {
#             "Unnamed: 7_level_1": "Langhendries Anatolie"
#         },
#         "Droits de succession en ligne collatérale et de mutation en ligne directe.": {
#             "Actif. (2)": "Déclare re…",
#             "Passif. (2)": null,
#             "Restant NET. (2)": null
#         },
#         "Droit de mutation par déces": {
#             "Valeur des immeubles. (2)": null
#         },
#         "Numéros des déclarations": {
#             "Primitives.": "243/1919",
#             "Supplémentaires.": null
#         },
#         "Date": {
#             "de l'expiration du délai de rectification.": "\"",
#             "de l'exigibilité des droits.": "\""
#         },
#         "Numéros de la consignation des droits au sommier n' 28": {
#             "Unnamed: 16_level_1": null
#         },
#         "Recette des droits et amendes.": {
#             "Date": "\"",
#             "N^03": "\""
#         },
#         "Cautionnements. ": {
#             "Numéros de la consignation au sommier n'30": null
#         },
#         "Observations": {
#             "(les déclarations qui figurent à l'état n'413 doivent être émargées en conséquence, dans la présnete colonne.)": null
#         }
#     },
#     {
#         "N' d'ordre": {
#             "Unnamed: 0_level_1": 426
#         },
#         "Date du dépot des déclarations": {
#             "Unnamed: 1_level_1": "d "
#         },
#         "Désignation des personnes décédées ou absentes.": {
#             "Nom.": "Fontignies",
#             "Prénoms": "Ida",
#             "Domiciles": "Rebcq",
#             "Domiciles.1": null
#         },
#         "Date du décès ous du judgement d'envoi en possession, en cas d'absence.": {
#             "Unnamed: 6_level_1": "24 juin 1919"
#         },
#         "Noms, Prénoms et demeures des parties déclarantes.": {
#             "Unnamed: 7_level_1": "Bartholomé Edouard & autres"
#         },
#         "Droits de succession en ligne collatérale et de mutation en ligne directe.": {
#             "Actif. (2)": 2361,
#             "Passif. (2)": null,
#             "Restant NET. (2)": 2361.0
#         },
#         "Droit de mutation par déces": {
#             "Valeur des immeubles. (2)": null
#         },
#         "Numéros des déclarations": {
#             "Primitives.": null,
#             "Supplémentaires.": null
#         },
#         "Date": {
#             "de l'expiration du délai de rectification.": "1 d",
#             "de l'exigibilité des droits.": "24 avril 1920"
#         },
#         "Numéros de la consignation des droits au sommier n' 28": {
#             "Unnamed: 16_level_1": null
#         },
#         "Recette des droits et amendes.": {
#             "Date": "20 avril 1920",
#             "N^03": 86
#         },
#         "Cautionnements. ": {
#             "Numéros de la consignation au sommier n'30": null
#         },
#         "Observations": {
#             "(les déclarations qui figurent à l'état n'413 doivent être émargées en conséquence, dans la présnete colonne.)": null
#         }
#     },
#     {
#         "N' d'ordre": {
#             "Unnamed: 0_level_1": 427
#         },
#         "Date du dépot des déclarations": {
#             "Unnamed: 1_level_1": "d "
#         },
#         "Désignation des personnes décédées ou absentes.": {
#             "Nom.": "Moens",
#             "Prénoms": "Joseph",
#             "Domiciles": "Tubize",
#             "Domiciles.1": null
#         },
#         "Date du décès ous du judgement d'envoi en possession, en cas d'absence.": {
#             "Unnamed: 6_level_1": "28 juillet 1919"
#         },
#         "Noms, Prénoms et demeures des parties déclarantes.": {
#             "Unnamed: 7_level_1": "Lange Eluè"
#         },
#         "Droits de succession en ligne collatérale et de mutation en ligne directe.": {
#             "Actif. (2)": 1576,
#             "Passif. (2)": null,
#             "Restant NET. (2)": 1576.0
#         },
#         "Droit de mutation par déces": {
#             "Valeur des immeubles. (2)": null
#         },
#         "Numéros des déclarations": {
#             "Primitives.": null,
#             "Supplémentaires.": null
#         },
#         "Date": {
#             "de l'expiration du délai de rectification.": "1d",
#             "de l'exigibilité des droits.": "28 mai 1920"
#         },
#         "Numéros de la consignation des droits au sommier n' 28": {
#             "Unnamed: 16_level_1": null
#         },
#         "Recette des droits et amendes.": {
#             "Date": "non passible",
#             "N^03": null
#         },
#         "Cautionnements. ": {
#             "Numéros de la consignation au sommier n'30": null
#         },
#         "Observations": {
#             "(les déclarations qui figurent à l'état n'413 doivent être émargées en conséquence, dans la présnete colonne.)": null
#         }
#     },
#     {
#         "N' d'ordre": {
#             "Unnamed: 0_level_1": 428
#         },
#         "Date du dépot des déclarations": {
#             "Unnamed: 1_level_1": "d "
#         },
#         "Désignation des personnes décédées ou absentes.": {
#             "Nom.": "Semal",
#             "Prénoms": "Heri",
#             "Domiciles": "Nivelles",
#             "Domiciles.1": null
#         },
#         "Date du décès ous du judgement d'envoi en possession, en cas d'absence.": {
#             "Unnamed: 6_level_1": "16 juin 1919"
#         },
#         "Noms, Prénoms et demeures des parties déclarantes.": {
#             "Unnamed: 7_level_1": "Gueret Alice & autres"
#         },
#         "Droits de succession en ligne collatérale et de mutation en ligne directe.": {
#             "Actif. (2)": 4000,
#             "Passif. (2)": null,
#             "Restant NET. (2)": 4000.0
#         },
#         "Droit de mutation par déces": {
#             "Valeur des immeubles. (2)": null
#         },
#         "Numéros des déclarations": {
#             "Primitives.": null,
#             "Supplémentaires.": "334/1920"
#         },
#         "Date": {
#             "de l'expiration du délai de rectification.": "1 d",
#             "de l'exigibilité des droits.": "16 avril 1920"
#         },
#         "Numéros de la consignation des droits au sommier n' 28": {
#             "Unnamed: 16_level_1": null
#         },
#         "Recette des droits et amendes.": {
#             "Date": "12 avril 1920",
#             "N^03": 79
#         },
#         "Cautionnements. ": {
#             "Numéros de la consignation au sommier n'30": null
#         },
#         "Observations": {
#             "(les déclarations qui figurent à l'état n'413 doivent être émargées en conséquence, dans la présnete colonne.)": null
#         }
#     }
# ]

# %%
# Example Image Data
def read_image_files(folder_path):
    example_paths = []

# Define the regex pattern
    pattern = re.compile(r'^example\d+.jpeg$')
    
    # Process each image file in the folder
    for file_name in os.listdir(folder_path):
        if pattern.match(file_name):
            file_path = os.path.join(folder_path, file_name)
            example_paths.append(file_path)

    return example_paths

# %%
def encode_image(image_path):
    with open(image_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode('utf-8')

# %%
all_images = read_image_files(image_folder)
all_images_encoded = [encode_image for image in all_images]

# %%
import requests

def create_example(prompt_example, encoded_img_ex, transcription_ex):
    return [
        {
            "role": "system",
            "content": [
                {
                    "type": "text",
                    "text": prompt_example
                },
                {
                    "type": "image_url",
                    "image_url": {
                        "url": f"data:image/jpeg;base64,{encoded_img_ex}"
                    }
                },
                {
                    "type": "text",
                    "text": transcription_ex
                }
            ]
        }
    ]

# %%
examples = []

prompt_example = "You are a helpful assistant, recreate the table from this handwritten document into a json file, this table contains columns and subcolumns. No PROFESSION column. Copy the texts as they are, do not add any other sentences from you:"

for i in range(len(all_images_encoded)):
    example = create_example(prompt_example, all_images_encoded[i], all_json_data[i])
    examples.append(example)

# %%
new_image_encoded = encode_image(image_folder+'/IMG_2024_03_19_11_46_52_911.jpeg')
prompt = "You are a helpful assistant, recreate the table from this handwritten document into a json file, this table contain columns and subcolums. No PROFESSION column. Copy the texts as they are, do not add any other sentences from you:"

# %%
User_input = {
            "role": "user",
            "content": [
                {
                    "type": "text",
                    "text": prompt
                },
                {
                    "type": "image_url",
                    "image_url": {
                        "url": f"data:image/jpeg;base64,{new_image_encoded}"
                    }
                }
            ]
        }

# %% [markdown]
# Too many examples? Errors occur with the examples... Should look for a new way? \
# Just do with `User_input` as messages and then iterate?

# %%
headers = {
    "Content-Type": "application/json",
    "Authorization": f"Bearer {openai_API_KEY}"
}

payload = {
    "model": "gpt-4o",
    "messages": examples + [User_input],
    "max_tokens": 1000,
    "temperature": 0
}

response = requests.post("https://api.openai.com/v1/chat/completions", headers=headers, json=payload)
print(response.json())
# Out:
# {'error': {'message': "Invalid type for 'messages[0]': expected an object, but got an array instead.", 'type': 'invalid_request_error', 'param': 'messages[0]', 'code': 'invalid_type'}}

# %% [markdown]
# # With Examples

# %%
def encode_image(image_path):
    with open(image_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode('utf-8')

# %%
def read_json(file_path):
    with open(file_path, 'r', encoding='utf-8') as json_file:
        json_data_pre = json.load(json_file)
        json_data =json.dumps(json_data_pre, indent=4, ensure_ascii=False)
    return json_data

# %% [markdown]
# ## Give already an example in the beginning

# %%
example_image = encode_image(path+'/data/Archives_LLN_Nivelles_I_1921_REG 5193/example2.jpeg')
example2_image = encode_image(path+'/data/Archives_LLN_Nivelles_I_1921_REG 5193/example3.jpeg')

input_image = encode_image(path+'/data/Archives_LLN_Nivelles_I_1921_REG 5193/example1.jpeg')
transcription_json = read_json(os.path.join(path, 'data/json_transcriptions/transcription_ex2.json'))
transcription2_json = read_json(os.path.join(path, 'data/json_transcriptions/transcription_ex3.json'))

# %% [markdown]
#                         In this case, add this information under a new key called 'Note' for the deceased person you saw in the previous row.
#                         If the row of the deceased's name does not exist in the previous row, just add this information about service dates under an empty person's json.
#
#                         Read the table in the image and organize the information in a nested json like the two examples.
#                         Make sure to read the names of the people and the location as well as the dates and the numbers correctly.
#                         When you see Arrêté le \d{2} \w+ \d{4}( \w+)? servais, add it to a new key key called 'Note'.
#                         If there is no information of the deceased name but only 'Arrêté le \d{2} \w+ \d{4}( \w+)? servais', add it under an empty name.
#                         Do not make up information.

# %%
headers = {
    "Content-Type": "application/json",
    "Authorization": f"Bearer {openai_API_KEY}"
}

payload = {
    "model": "gpt-4o",
    "messages":  [
                {
                    "role": "system", 
                    "content": "You are a helpful assistant who can read old handwriting."
                },
                {
                    "role": "user",
                    "content": [
                    {
                        "type": "text",
                        "text": f"""
                        Transcription:
                        ```json
                        {transcription_json}
                        ```
                        
                        The ```json block contains the transcription of the following image organized in a nested json:
                        
                        """
                    },
                    {
                        "type": "image_url",
                        "image_url": {
                        "url": f"data:image/jpeg;base64,{example_image}"
                        }
                    }
                    ]
                },
                {
                    "role": "user",
                    "content": [
                    {
                        "type": "text",
                        "text": """
                        Task:
                        Firstly, look at the layout of the table in the image. It should be the same as the example.
                        
                        Secondly, read the table row by row. Each row should represent information about a deceased person. 
                        Some rows begin with the name of the deceased. Some row only indicates the serviced date in the form of 'Arrêté le \d{2} \w+ \d{4}( \w+)? servais'. 
                        
                        Thirdly, ensure that you read the numbers correctly by comparing the handwritings in the example and also within the new image.
                        'Restant Net.' must be the result of 'Actif.' minus 'Passif.'. 
                        
                        Fourthly, organize the read texts in a nested json like in the example.
                        
                        Lastly, think about what could have read wrongly. Refine it. Indicate the parts you are unsure with an asterisk. 
                        
                        """
                    },
                    {
                        "type": "image_url",
                        "image_url": {
                        "url": f"data:image/jpeg;base64,{input_image}"
                        }
                    }
                    ]
                }
        
                ],
    "max_tokens": 3000,
    "temperature": 0
}

response = requests.post("https://api.openai.com/v1/chat/completions", headers=headers, json=payload)

# %%
content = response.json()["choices"][0]["message"]["content"]
print(content)
# Out:
# Here is the transcription of the table from the new image, organized in a nested JSON format. I have carefully read the table row by row and ensured the numbers are correct by comparing the handwriting within the image. I have also indicated parts I am unsure about with an asterisk (*).
#
# ```json
# [
#     {
#         "N' d'ordre": {
#             "Unnamed: 0_level_1": 411
#         },
#         "Date du dépot des déclarations": {
#             "Unnamed: 1_level_1": "sept 9bre"
#         },
#         "Désignation des personnes décédées ou absentes.": {
#             "Nom.": "Fievereent",
#             "Prénoms": "Adolphe",
#             "Domiciles": "Ophain",
#             "Note": NaN
#         },
#         "Date du décès ous du judgement d'envoi en possession, en cas d'absence.": {
#             "Unnamed: 6_level_1": "19 octobre 1919"
#         },
#         "Noms, Prénoms et demeures des parties déclarantes.": {
#             "Unnamed: 7_level_1": "Fievereent Henri & autres"
#         },
#         "Droits de succession en ligne collatérale et de mutation en ligne directe.": {
#             "Actif. (2)": 8000,
#             "Passif. (2)": 2000.0,
#             "Restant NET. (2)": 6000.0
#         },
#         "Droit de mutation par déces": {
#             "Valeur des immeubles. (2)": NaN
#         },
#         "Numéros des déclarations": {
#             "Primitives.": NaN,
#             "Supplémentaires.": NaN
#         },
#         "Date": {
#             "de l'expiration du délai de rectification.": "19 avril 1920",
#             "de l'exigibilité des droits.": "19 avril 1920"
#         },
#         "Numéros de la consignation des droits au sommier n' 28": {
#             "Unnamed: 16_level_1": NaN
#         },
#         "Recette des droits et amendes.": {
#             "Date": "19 avril 1920",
#             "N^03": 54.0
#         },
#         "Cautionnements. ": {
#             "Numéros de la consignation au sommier n'30": NaN
#         },
#         "Observations": {
#             "(les déclarations qui figurent à l'état n'413 doivent être émargées en conséquence, dans la présnete colonne.)": NaN
#         }
#     },
#     {
#         "N' d'ordre": {
#             "Unnamed: 0_level_1": 412
#         },
#         "Date du dépot des déclarations": {
#             "Unnamed: 1_level_1": "sept 9bre"
#         },
#         "Désignation des personnes décédées ou absentes.": {
#             "Nom.": "Lefevre",
#             "Prénoms": "Julie",
#             "Domiciles": "Fayt",
#             "Note": NaN
#         },
#         "Date du décès ous du judgement d'envoi en possession, en cas d'absence.": {
#             "Unnamed: 6_level_1": "19 octobre 1919"
#         },
#         "Noms, Prénoms et demeures des parties déclarantes.": {
#             "Unnamed: 7_level_1": "Lefevre Marie & autres"
#         },
#         "Droits de succession en ligne collatérale et de mutation en ligne directe.": {
#             "Actif. (2)": 6000,
#             "Passif. (2)": 1000.0,
#             "Restant NET. (2)": 5000.0
#         },
#         "Droit de mutation par déces": {
#             "Valeur des immeubles. (2)": NaN
#         },
#         "Numéros des déclarations": {
#             "Primitives.": NaN,
#             "Supplémentaires.": NaN
#         },
#         "Date": {
#             "de l'expiration du délai de rectification.": "19 avril 1920",
#             "de l'exigibilité des droits.": "19 avril 1920"
#         },
#         "Numéros de la consignation des droits au sommier n' 28": {
#             "Unnamed: 16_level_1": NaN
#         },
#         "Recette des droits et amendes.": {
#             "Date": "19 avril 1920",
#             "N^03": 54.0
#         },
#         "Cautionnements. ": {
#             "Numéros de la consignation au sommier n'30": NaN
#         },
#         "Observations": {
#             "(les déclarations qui figurent à l'état n'413 doivent être émargées en conséquence, dans la présnete colonne.)": NaN
#         }
#     },
#     {
#         "N' d'ordre": {
#             "Unnamed: 0_level_1": NaN
#         },
#         "Date du dépot des déclarations": {
#             "Unnamed: 1_level_1": NaN
#         },
#         "Désignation des personnes décédées ou absentes.": {
#             "Nom.": NaN,
#             "Prénoms": NaN,
#             "Domiciles": NaN,
#             "Note": "Arrêté le vingt-six octobre 1919 servais"
#         },
#         "Date du décès ous du judgement d'envoi en possession, en cas d'absence.": {
#             "Unnamed: 6_level_1": NaN
#         },
#         "Noms, Prénoms et demeures des parties déclarantes.": {
#             "Unnamed: 7_level_1": NaN
#         },
#         "Droits de succession en ligne collatérale et de mutation en ligne directe.": {
#             "Actif. (2)": NaN,
#             "Passif. (2)": NaN,
#             "Restant NET. (2)": NaN
#         },
#         "Droit de mutation par déces": {
#             "Valeur des immeubles. (2)": NaN
#         },
#         "Numéros des déclarations": {
#             "Primitives.": NaN,
#             "Supplémentaires.": NaN
#         },
#         "Date": {
#             "de l'expiration du délai de rectification.": NaN,
#             "de l'exigibilité des droits.": NaN
#         },
#         "Numéros de la consignation des droits au sommier n' 28": {
#             "Unnamed: 16_level_1": NaN
#         },
#         "Recette des droits et amendes.": {
#             "Date": NaN,
#             "N^03": NaN
#         },
#         "Cautionnements. ": {
#             "Numéros de la consignation au sommier n'30": NaN
#         },
#         "Observations": {
#             "(les déclarations qui figurent à l'état n'413 doivent être émargées en conséquence, dans la présnete colonne.)": NaN
#         }
#     },
#     {
#         "N' d'ordre": {
#             "Unnamed: 0_level_1": NaN
#         },
#         "Date du dépot des déclarations": {
#             "Unnamed: 1_level_1": NaN
#         },
#         "Désignation des personnes décédées ou absentes.": {
#             "Nom.": NaN,
#             "Prénoms": NaN,
#             "Domiciles": NaN,
#             "Note": "Arrêté le vingt-sept octobre 1919 servais"
#         },
#         "Date du décès ous du judgement d'envoi en possession, en cas d'absence.": {
#             "Unnamed: 6_level_1": NaN
#         },
#         "Noms, Prénoms et demeures des parties déclarantes.": {
#             "Unnamed: 7_level_1": NaN
#         },
#         "Droits de succession en ligne collatérale et de mutation en ligne directe.": {
#             "Actif. (2)": NaN,
#             "Passif. (2)": NaN,
#             "Restant NET. (2)": NaN
#         },
#         "Droit de mutation par déces": {
#             "Valeur des immeubles. (2)": NaN
#         },
#         "Numéros des déclarations": {
#             "Primitives.": NaN,
#             "Supplémentaires.": NaN
#         },
#         "Date": {
#             "de l'expiration du délai de rectification.": NaN,
#             "de l'exigibilité des droits.": NaN
#         },
#         "Numéros de la consignation des droits au sommier n' 28": {
#             "Unnamed: 16_level_1": NaN
#         },
#         "Recette des droits et amendes.": {
#             "Date": NaN,
#             "N^03": NaN
#         },
#         "Cautionnements. ": {
#             "Numéros de la consignation au sommier n'30": NaN
#         },
#         "Observations": {
#             "(les déclarations qui figurent à l'état n'413 doivent être émargées en conséquence, dans la présnete colonne.)": NaN
#         }
#     },
#     {
#         "N' d'ordre": {
#             "Unnamed: 0_level_1": NaN
#         },
#         "Date du dépot des déclarations": {
#             "Unnamed: 1_level_1": NaN
#         },
#         "Désignation des personnes décédées ou absentes.": {
#             "Nom.": NaN,
#             "Prénoms": NaN,
#             "Domiciles": NaN,
#             "Note": "Arrêté le premier novembre 1919 servais"
#         },
#         "Date du décès ous du judgement d'envoi en possession, en cas d'absence.": {
#             "Unnamed: 6_level_1": NaN
#         },
#         "Noms, Prénoms et demeures des parties déclarantes.": {
#             "Unnamed: 7_level_1": NaN
#         },
#         "Droits de succession en ligne collatérale et de mutation en ligne directe.": {
#             "Actif. (2)": NaN,
#             "Passif. (2)": NaN,
#             "Restant NET. (2)": NaN
#         },
#         "Droit de mutation par déces": {
#             "Valeur des immeubles. (2)": NaN
#         },
#         "Numéros des déclarations": {
#             "Primitives.": NaN,
#             "Supplémentaires.": NaN
#         },
#         "Date": {
#             "de l'expiration du délai de rectification.": NaN,
#             "de l'exigibilité des droits.": NaN
#         },
#         "Numéros de la consignation des droits au sommier n' 28": {
#             "Unnamed: 16_level_1": NaN
#         },
#         "Recette des droits et amendes.": {
#             "Date": NaN,
#             "N^03": NaN
#         },
#         "Cautionnements. ": {
#             "Numéros de la consignation au sommier n'30": NaN
#         },
#         "Observations": {
#             "(les déclarations qui figurent à l'état n'413 doivent être émargées en conséquence, dans la présnete colonne.)": NaN
#         }
#     },
#     {
#         "N' d'ordre": {
#             "Unnamed: 0_level_1": 413
#         },
#         "Date du dépot des déclarations": {
#             "Unnamed: 1_level_1": "dix 9bre"
#         },
#         "Désignation des personnes décédées ou absentes.": {
#             "Nom.": "Desmedt",
#             "Prénoms": "Jeanne",
#             "Domiciles": "Nivelles",
#             "Note": NaN
#         },
#         "Date du décès ous du judgement d'envoi en possession, en cas d'absence.": {
#             "Unnamed: 6_level_1": "16 avril 1919"
#         },
#         "Noms, Prénoms et demeures des parties déclarantes.": {
#             "Unnamed: 7_level_1": "Desmedt Marie & autres"
#         },
#         "Droits de succession en ligne collatérale et de mutation en ligne directe.": {
#             "Actif. (2)": 5000,
#             "Passif. (2)": 1000.0,
#             "Restant NET. (2)": 4000.0
#         },
#         "Droit de mutation par déces": {
#             "Valeur des immeubles. (2)": NaN
#         },
#         "Numéros des déclarations": {
#             "Primitives.": NaN,
#             "Supplémentaires.": NaN
#         },
#         "Date": {
#             "de l'expiration du délai de rectification.": "16 avril 1920",
#             "de l'exigibilité des droits.": "16 avril 1920"
#         },
#         "Numéros de la consignation des droits au sommier n' 28": {
#             "Unnamed: 16_level_1": NaN
#         },
#         "Recette des droits et amendes.": {
#             "Date": "16 avril 1920",
#             "N^03": 54.0
#         },
#         "Cautionnements. ": {
#             "Numéros de la consignation au sommier n'30": NaN
#         },
#         "Observations": {
#             "(les déclarations qui figurent à l'état n'413 doivent être émargées en conséquence, dans la présnete colonne.)": NaN
#         }
#     },
#     {
#         "N' d'ordre": {
#             "Unnamed: 0_level_1": 414
#         },
#         "Date du dépot des déclarations": {
#             "Unnamed: 1_level_1

# %% [markdown]
# ## Separately

# %%
def call(prompt, max_tokens =1000, base64_image=None):
        headers = {
            "Content-Type": "application/json",
            "Authorization": f"Bearer {openai_API_KEY}"
        } 
        if base64_image:  
            payload = {
                "model": "gpt-4o",
                "messages": [
                {
                    "role": "system", 
                    "content": "You are a helpful assistant who can read old handwriting."},
                {
                    "role": "user",
                    "content": [
                    {
                        "type": "text",
                        "text": prompt
                    },
                    {
                        "type": "image_url",
                        "image_url": {
                        "url": f"data:image/jpeg;base64,{base64_image}"
                        }
                    }
                    ]
                }
                ],
                "max_tokens": max_tokens,
                "temperature": 0,
                # "logit_bias": {"1734": -100},
                "response_format": { "type": "json_object" }
            }
        else:
            payload = {
                "model": "gpt-4o",
                "messages": [
                {
                    "role": "user",
                    "content": [
                    {
                        "type": "text",
                        "text": prompt
                    }
                    ]
                }
                ],
                "max_tokens": max_tokens,
                "temperature": 0,
                # "logit_bias": {"1734": -100},
                "response_format":{ "type": "json_object" }
            }
        
        response = requests.post("https://api.openai.com/v1/chat/completions", headers=headers, json=payload)
        # return response.json()["choices"][0]["message"]["content"]
        return response

# %%
def makeDraft(image_path, output_format = "json"):
    base64_image = encode_image(image_path)
    
    prompt = f"""
        Structure:
                "N' d'ordre":
                ,
                "Date du dépot des déclarations": 
                ,
                "Désignation des personnes décédées ou absentes.": 
                    "Nom.":  ,
                    "Prénoms":  ,
                    "Domiciles": 
                ,
                "Date du décès ous du judgement d'envoi en possession, en cas d'absence.": 
                ,
                "Noms, Prénoms et demeures des parties déclarantes.": 
                ,
                "Droits de succession en ligne collatérale et de mutation en ligne directe.": 
                    "Actif. (2)": ,
                    "Passif. (2)": ,
                    "Restant NET. (2)": 
                ,
                "Droit de mutation par déces": 
                    "Valeur des immeubles. (2)": 
                ,
                "Numéros des déclarations": 
                    "Primitives.": ,
                    "Supplémentaires.": 
                ,
                "Date": 
                    "de l'expiration du délai de rectification.": ,
                    "de l'exigibilité des droits.": 
                ,
                "Numéros de la consignation des droits au sommier n' 28": 
                ,
                "Recette des droits et amendes.": 
                    "Date": ,
                    "N^03": 
                ,
                "Cautionnements. ": 
                    "Numéros de la consignation au sommier n'30":
                ,
                "Observations (les déclarations qui figurent à l'état n'413 doivent être émargées en conséquence, dans la présnete colonne.)": 
 
        
        Notations:
            7bre or 7b == September
            8bre or 8b == October
            9bre or 9b == November
            Dbre or Db == December
            d or " (quotation mark) = ditto    
        
        Tips: 
        The table in the image is a Déclaration de succession of Belgium. 
        Each deceased person should have information in the following structure below.
        Some notations for dates and others are used as indicated in Notations, but return the notations as they are seen, not what they mean.
        Information for 'Actif.', 'Passif.' and 'Restant Net.' should exist for each dead person. So, read them well from the image.
        'Restant Net.' is the result of 'Actif.' minus 'Passif.'.
        
        Task: 
        Please recreate the table in the image as a {output_format} file based on this structure.
        When you see Arrêté le \d{2} \w+ \d{4}( \w+)? servais, add it to a new key key called 'Note'. 
        If there is no information of the deceased name but only 'Arrêté le \d{2} \w+ \d{4}( \w+)? servais', add it under an empty name.
        Make sure to read the names of the people and the location as well as the dates and the numbers correctly.
        Do not make up information. 
    """
    return call(prompt, max_tokens=3000, base64_image = base64_image), base64_image

# %%
draft, encoded_image = makeDraft(image_path = path+'/data/Archives_LLN_Nivelles_I_1921_REG 5193/example1.jpeg')

# %%
draft_json = draft.json()["choices"][0]["message"]["content"]

# %%
print(draft_json)
# Out:
# {
#     "entries": [
#         {
#             "N' d'ordre": "6",
#             "Date du dépot des déclarations": "1897 8bre",
#             "Désignation des personnes décédées ou absentes": {
#                 "Nom": "",
#                 "Prénoms": "",
#                 "Domiciles": ""
#             },
#             "Date du décès ous du judgement d'envoi en possession, en cas d'absence": "Arrêté le 10 8bre 1897 servais",
#             "Noms, Prénoms et demeures des parties déclarantes": "",
#             "Droits de succession en ligne collatérale et de mutation en ligne directe": {
#                 "Actif. (2)": "",
#                 "Passif. (2)": "",
#                 "Restant NET. (2)": ""
#             },
#             "Droit de mutation par déces": {
#                 "Valeur des immeubles. (2)": ""
#             },
#             "Numéros des déclarations": {
#                 "Primitives": "",
#                 "Supplémentaires": ""
#             },
#             "Date": {
#                 "de l'expiration du délai de rectification": "",
#                 "de l'exigibilité des droits": ""
#             },
#             "Numéros de la consignation des droits au sommier n' 28": "",
#             "Recette des droits et amendes": {
#                 "Date": "",
#                 "N^03": ""
#             },
#             "Cautionnements": {
#                 "Numéros de la consignation au sommier n'30": ""
#             },
#             "Observations (les déclarations qui figurent à l'état n'413 doivent être émargées en conséquence, dans la présnete colonne.)": "",
#             "Note": "Arrêté le 10 8bre 1897 servais"
#         },
#         {
#             "N' d'ordre": "6",
#             "Date du dépot des déclarations": "1897 8bre",
#             "Désignation des personnes décédées ou absentes": {
#                 "Nom": "Lebeurent",
#                 "Prénoms": "Adolphe",
#                 "Domiciles": "Ophain"
#             },
#             "Date du décès ous du judgement d'envoi en possession, en cas d'absence": "Arrêté le 10 8bre 1897 servais",
#             "Noms, Prénoms et demeures des parties déclarantes": "Lebeurent Henri et autres",
#             "Droits de succession en ligne collatérale et de mutation en ligne directe": {
#                 "Actif. (2)": "2299",
#                 "Passif. (2)": "2299",
#                 "Restant NET. (2)": "2299"
#             },
#             "Droit de mutation par déces": {
#                 "Valeur des immeubles. (2)": "2299"
#             },
#             "Numéros des déclarations": {
#                 "Primitives": "",
#                 "Supplémentaires": ""
#             },
#             "Date": {
#                 "de l'expiration du délai de rectification": "",
#                 "de l'exigibilité des droits": ""
#             },
#             "Numéros de la consignation des droits au sommier n' 28": "",
#             "Recette des droits et amendes": {
#                 "Date": "",
#                 "N^03": ""
#             },
#             "Cautionnements": {
#                 "Numéros de la consignation au sommier n'30": ""
#             },
#             "Observations (les déclarations qui figurent à l'état n'413 doivent être émargées en conséquence, dans la présnete colonne.)": ""
#         },
#         {
#             "N' d'ordre": "6",
#             "Date du dépot des déclarations": "1897 8bre",
#             "Désignation des personnes décédées ou absentes": {
#                 "Nom": "Lefevre",
#                 "Prénoms": "Jules",
#                 "Domiciles": "Francis et Francois"
#             },
#             "Date du décès ous du judgement d'envoi en possession, en cas d'absence": "Arrêté le 10 8bre 1897 servais",
#             "Noms, Prénoms et demeures des parties déclarantes": "Lefevre Marie",
#             "Droits de succession en ligne collatérale et de mutation en ligne directe": {
#                 "Actif. (2)": "2299",
#                 "Passif. (2)": "2299",
#                 "Restant NET. (2)": "2299"
#             },
#             "Droit de mutation par déces": {
#                 "Valeur des immeubles. (2)": "2299"
#             },
#             "Numéros des déclarations": {
#                 "Primitives": "",
#                 "Supplémentaires": ""
#             },
#             "Date": {
#                 "de l'expiration du délai de rectification": "",
#                 "de l'exigibilité des droits": ""
#             },
#             "Numéros de la consignation des droits au sommier n' 28": "",
#             "Recette des droits et amendes": {
#                 "Date": "",
#                 "N^03": ""
#             },
#             "Cautionnements": {
#                 "Numéros de la consignation au sommier n'30": ""
#             },
#             "Observations (les déclarations qui figurent à l'état n'413 doivent être émargées en conséquence, dans la présnete colonne.)": ""
#         },
#         {
#             "N' d'ordre": "6",
#             "Date du dépot des déclarations": "1897 9bre",
#             "Désignation des personnes décédées ou absentes": {
#                 "Nom": "",
#                 "Prénoms": "",
#                 "Domiciles": ""
#             },
#             "Date du décès ous du judgement d'envoi en possession, en cas d'absence": "Arrêté le 10 9bre 1897 servais",
#             "Noms, Prénoms et demeures des parties déclarantes": "",
#             "Droits de succession en ligne collatérale et de mutation en ligne directe": {
#                 "Actif. (2)": "",
#                 "Passif. (2)": "",
#                 "Restant NET. (2)": ""
#             },
#             "Droit de mutation par déces": {
#                 "Valeur des immeubles. (2)": ""
#             },
#             "Numéros des déclarations": {
#                 "Primitives": "",
#                 "Supplémentaires": ""
#             },
#             "Date": {
#                 "de l'expiration du délai de rectification": "",
#                 "de l'exigibilité des droits": ""
#             },
#             "Numéros de la consignation des droits au sommier n' 28": "",
#             "Recette des droits et amendes": {
#                 "Date": "",
#                 "N^03": ""
#             },
#             "Cautionnements": {
#                 "Numéros de la consignation au sommier n'30": ""
#             },
#             "Observations (les déclarations qui figurent à l'état n'413 doivent être émargées en conséquence, dans la présnete colonne.)": "",
#             "Note": "Arrêté le 10 9bre 1897 servais"
#         },
#         {
#             "N' d'ordre": "6",
#             "Date du dépot des déclarations": "1897 9bre",
#             "Désignation des personnes décédées ou absentes": {
#                 "Nom": "Desmedt",
#                 "Prénoms": "Jeanne",
#                 "Domiciles": "Nivelles"
#             },
#             "Date du décès ous du judgement d'envoi en possession, en cas d'absence": "Arrêté le 10 9bre 1897 servais",
#             "Noms, Prénoms et demeures des parties déclarantes": "Desmedt Marie et autres",
#             "Droits de succession en ligne collatérale et de mutation en ligne directe": {
#                 "Actif. (2)": "2299",
#                 "Passif. (2)": "2299",
#                 "Restant NET. (2)": "2299"
#             },
#             "Droit de mutation par déces": {
#                 "Valeur des immeubles. (2)": "2299"
#             },
#             "Numéros des déclarations": {
#                 "Primitives": "",
#                 "Supplémentaires": ""
#             },
#             "Date": {
#                 "de l'expiration du délai de rectification": "",
#                 "de l'exigibilité des droits": ""
#             },
#             "Numéros de la consignation des droits au sommier n' 28": "",
#             "Recette des droits et amendes": {
#                 "Date": "",
#                 "N^03": ""
#             },
#             "Cautionnements": {
#                 "Numéros de la consignation au sommier n'30": ""
#             },
#             "Observations (les déclarations qui figurent à l'état n'413 doivent être émargées en conséquence, dans la présnete colonne.)": ""
#         },
#         {
#             "N' d'ordre": "6",
#             "Date du dépot des déclarations": "1897 9bre",
#             "Désignation des personnes décédées ou absentes": {
#                 "Nom": "Monseu",
#                 "Prénoms": "Marie",
#                 "Domiciles": "Chastre"
#             },
#             "Date du décès ous du judgement d'envoi en possession, en cas d'absence": "Arrêté le 10 9bre 1897 servais",
#             "Noms, Prénoms et demeures des parties déclarantes": "Monseu Charles",
#             "Droits de succession en ligne collatérale et de mutation en ligne directe": {
#                 "Actif. (2)": "2299",
#                 "Passif. (2)": "2299",
#                 "Restant NET. (2)": "2299"
#             },
#             "Droit de mutation par déces": {
#                 "Valeur des immeubles. (2)": "2299"
#             },
#             "Numéros des déclarations": {
#                 "Primitives": "",
#                 "Supplémentaires": ""
#             },
#             "Date": {
#                 "de l'expiration du délai de rectification": "",
#                 "de l'exigibilité des droits": ""
#             },
#             "Numéros de la consignation des droits au sommier n' 28": "",
#             "Recette des droits et amendes": {
#                 "Date": "",
#                 "N^03": ""
#             },
#             "Cautionnements": {
#                 "Numéros de la consignation au sommier n'30": ""
#             },
#             "Observations (les déclarations qui figurent à l'état n'413 doivent être émargées en conséquence, dans la présnete colonne.)": ""
#         },
#         {
#             "N' d'ordre": "6",
#             "Date du dépot des déclarations": "1897 9bre",
#             "Désignation des personnes décédées ou absentes": {
#                 "Nom": "Bouly",
#                 "Prénoms": "Jean",
#                 "Domiciles": "Nivelles"
#             },
#             "Date du décès ous du judgement d'envoi en possession, en cas d'absence": "Arrêté le 10 9bre 1897 servais",
#             "Noms, Prénoms et demeures des parties déclarantes": "Bouly Henri et autres",
#             "Droits de succession en ligne collatérale et de mutation en ligne directe": {
#                 "Actif. (2)": "2299",
#                 "Passif. (2)": "2299",
#                 "Restant NET. (2)": "2299"
#             },
#             "Droit de mutation par déces": {
#                 "Valeur des immeubles. (2)": "2299"
#             },
#             "Numéros des déclarations": {
#                 "Primitives": "",
#                 "Supplémentaires": ""
#             },
#             "Date": {
#                 "de l'expiration du délai de rectification": "",
#                 "de l'exigibilité des droits": ""
#             },
#             "Numéros de la consignation des droits au sommier n' 28": "",
#             "Recette des droits et amendes": {
#                 "Date": "",
#                 "N^03": ""
#             },
#             "Cautionnements": {
#                 "Numéros de la consignation au sommier n'30": ""
#             },
#             "Observations (les déclarations qui figurent à l'état n'413 doivent être émargées en conséquence, dans la présnete colonne.)": ""
#         },
#         {
#             "N' d'ordre": "6",
#             "Date du dépot des déclarations": "1897 9bre",
#             "Désignation des personnes décédées ou absentes": {
#                 "Nom": "Godart",
#                 "Prénoms": "Armand",
#                 "Domiciles": "Nivelles"
#             },
#             "Date du décès ous du judgement d'envoi en possession, en cas d'absence": "Arrêté le 10 9bre 1897 servais",
#             "Noms, Prénoms et demeures des parties déclarantes": "Godart Henri et autres",
#             "Droits de succession en ligne collatérale et de mutation en ligne directe": {
#                 "Actif. (2)": "2299",
#                 "Passif. (2)": "2299",
#                 "Restant NET. (2)": "2299"
#             },
#             "Droit de mutation par déces": {
#                 "Valeur des immeubles. (2)": "2299"
#             },
#             "Numéros des déclarations": {
#                 "Primitives": "",
#                 "Supplémentaires": ""
#             },
#             "Date": {
#                 "de l'expiration du délai de rectification": "",
#                 "de l'exigibilité des droits": ""
#             },
#             "Numéros de la consignation des droits au sommier n' 28": "",
#             "Recette des droits et amendes": {
#                 "Date": "",
#                 "N^03": ""
#             },
#             "Cautionnements": {
#                 "Numéros de la consignation au sommier n'30": ""

# %%
 def refineLayout(draft, json_path):
        
    all_json_data = read_json(json_path)   
 
    prompt = f"""
        
        Your first draft:
        ```draft
        {draft}
        ```
        
        Example:
        ```json
        {all_json_data}
        ```  

        Errors: 
        Your first draft in the ```draft block contains some errors. 
        
        Context: 
        The content of your draft in ```draft block should follow the structure in the example in the ```json block. 
        Information for 'Actif.', 'Passif.' and 'Restant Net.' should exist for each dead person. So, read them well from the image.
        'Restant Net.' is 'Actif.' - 'Passif.'
        
        Task:
        Refine your first draft based on the example and the image.
        When you see Arrêté le \d{2} \w+ \d{4}( \w+)? servais, add it to a new key key called 'Note'. 
        If there is no information of the deceased name but only 'Arrêté le \d{2} \w+ \d{4}( \w+)? servais', add it under an empty name.
        Make sure to read the names of the people and the location as well as the dates and the numbers correctly.
        Do not make up information. 
        
        """
    return call(prompt, max_tokens = 3000, base64_image = encoded_image)

# %%
refine = refineLayout(draft_json, json_path = os.path.join(path, 'data/json_transcriptions/transcription_ex2.json'))

# %%
refine_json = refine.json()["choices"][0]["message"]["content"]
print(refine_json)
# Out:
#        {
#     "entries": [
#         {
#             "N' d'ordre": "6",
#             "Date du dépot des déclarations": "1897 8bre",
#             "Désignation des personnes décédées ou absentes": {
#                 "Nom": "",
#                 "Prénoms": "",
#                 "Domiciles": ""
#             },
#             "Date du décès ous du jugement d'envoi en possession, en cas d'absence": "",
#             "Noms, Prénoms et demeures des parties déclarantes": "",
#             "Droits de succession en ligne collatérale et de mutation en ligne directe": {
#                 "Actif. (2)": "",
#                 "Passif. (2)": "",
#                 "Restant NET. (2)": ""
#             },
#             "Droit de mutation par décès": {
#                 "Valeur des immeubles. (2)": ""
#             },
#             "Numéros des déclarations": {
#                 "Primitives.": "",
#                 "Supplémentaires.": ""
#             },
#             "Date": {
#                 "de l'expiration du délai de rectification": "",
#                 "de l'exigibilité des droits": ""
#             },
#             "Numéros de la consignation des droits au sommier n' 28": "",
#             "Recette des droits et amendes": {
#                 "Date": "",
#                 "N^03": ""
#             },
#             "Cautionnements": {
#                 "Numéros de la consignation au sommier n'30": ""
#             },
#             "Observations": "",
#             "Note": "Arrêté le 10 7bre 1897 servais"
#         },
#         {
#             "N' d'ordre": "6",
#             "Date du dépot des déclarations": "1897 8bre",
#             "Désignation des personnes décédées ou absentes": {
#                 "Nom": "Lebevaert",
#                 "Prénoms": "Adolphe",
#                 "Domiciles": "Ophain"
#             },
#             "Date du décès ous du jugement d'envoi en possession, en cas d'absence": "",
#             "Noms, Prénoms et demeures des parties déclarantes": "Lebevaert Henri à autre",
#             "Droits de succession en ligne collatérale et de mutation en ligne directe": {
#                 "Actif. (2)": "2299",
#                 "Passif. (2)": "2299",
#                 "Restant NET. (2)": "0"
#             },
#             "Droit de mutation par décès": {
#                 "Valeur des immeubles. (2)": "2299"
#             },
#             "Numéros des déclarations": {
#                 "Primitives.": "",
#                 "Supplémentaires.": ""
#             },
#             "Date": {
#                 "de l'expiration du délai de rectification": "",
#                 "de l'exigibilité des droits": ""
#             },
#             "Numéros de la consignation des droits au sommier n' 28": "",
#             "Recette des droits et amendes": {
#                 "Date": "",
#                 "N^03": ""
#             },
#             "Cautionnements": {
#                 "Numéros de la consignation au sommier n'30": ""
#             },
#             "Observations": "",
#             "Note": "Arrêté le 10 7bre 1897 servais"
#         },
#         {
#             "N' d'ordre": "6",
#             "Date du dépot des déclarations": "1897 8bre",
#             "Désignation des personnes décédées ou absentes": {
#                 "Nom": "Lefevre",
#                 "Prénoms": "Jules",
#                 "Domiciles": "Francis"
#             },
#             "Date du décès ous du jugement d'envoi en possession, en cas d'absence": "",
#             "Noms, Prénoms et demeures des parties déclarantes": "Lefevre Marie",
#             "Droits de succession en ligne collatérale et de mutation en ligne directe": {
#                 "Actif. (2)": "2299",
#                 "Passif. (2)": "2299",
#                 "Restant NET. (2)": "0"
#             },
#             "Droit de mutation par décès": {
#                 "Valeur des immeubles. (2)": "2299"
#             },
#             "Numéros des déclarations": {
#                 "Primitives.": "",
#                 "Supplémentaires.": ""
#             },
#             "Date": {
#                 "de l'expiration du délai de rectification": "",
#                 "de l'exigibilité des droits": ""
#             },
#             "Numéros de la consignation des droits au sommier n' 28": "",
#             "Recette des droits et amendes": {
#                 "Date": "",
#                 "N^03": ""
#             },
#             "Cautionnements": {
#                 "Numéros de la consignation au sommier n'30": ""
#             },
#             "Observations": "",
#             "Note": "Arrêté le 10 7bre 1897 servais"
#         },
#         {
#             "N' d'ordre": "6",
#             "Date du dépot des déclarations": "1897 8bre",
#             "Désignation des personnes décédées ou absentes": {
#                 "Nom": "",
#                 "Prénoms": "",
#                 "Domiciles": ""
#             },
#             "Date du décès ous du jugement d'envoi en possession, en cas d'absence": "",
#             "Noms, Prénoms et demeures des parties déclarantes": "",
#             "Droits de succession en ligne collatérale et de mutation en ligne directe": {
#                 "Actif. (2)": "",
#                 "Passif. (2)": "",
#                 "Restant NET. (2)": ""
#             },
#             "Droit de mutation par décès": {
#                 "Valeur des immeubles. (2)": ""
#             },
#             "Numéros des déclarations": {
#                 "Primitives.": "",
#                 "Supplémentaires.": ""
#             },
#             "Date": {
#                 "de l'expiration du délai de rectification": "",
#                 "de l'exigibilité des droits": ""
#             },
#             "Numéros de la consignation des droits au sommier n' 28": "",
#             "Recette des droits et amendes": {
#                 "Date": "",
#                 "N^03": ""
#             },
#             "Cautionnements": {
#                 "Numéros de la consignation au sommier n'30": ""
#             },
#             "Observations": "",
#             "Note": "Arrêté le 10 7bre 1897 servais"
#         },
#         {
#             "N' d'ordre": "6",
#             "Date du dépot des déclarations": "1897 8bre",
#             "Désignation des personnes décédées ou absentes": {
#                 "Nom": "Desmedt",
#                 "Prénoms": "Jeanne",
#                 "Domiciles": "Nivelles"
#             },
#             "Date du décès ous du jugement d'envoi en possession, en cas d'absence": "",
#             "Noms, Prénoms et demeures des parties déclarantes": "Desmedt Henri",
#             "Droits de succession en ligne collatérale et de mutation en ligne directe": {
#                 "Actif. (2)": "2299",
#                 "Passif. (2)": "2299",
#                 "Restant NET. (2)": "0"
#             },
#             "Droit de mutation par décès": {
#                 "Valeur des immeubles. (2)": "2299"
#             },
#             "Numéros des déclarations": {
#                 "Primitives.": "",
#                 "Supplémentaires.": ""
#             },
#             "Date": {
#                 "de l'expiration du délai de rectification": "",
#                 "de l'exigibilité des droits": ""
#             },
#             "Numéros de la consignation des droits au sommier n' 28": "",
#             "Recette des droits et amendes": {
#                 "Date": "",
#                 "N^03": ""
#             },
#             "Cautionnements": {
#                 "Numéros de la consignation au sommier n'30": ""
#             },
#             "Observations": "",
#             "Note": "Arrêté le 10 7bre 1897 servais"
#         },
#         {
#             "N' d'ordre": "6",
#             "Date du dépot des déclarations": "1897 8bre",
#             "Désignation des personnes décédées ou absentes": {
#                 "Nom": "Monseu",
#                 "Prénoms": "Marie",
#                 "Domiciles": "Chastre"
#             },
#             "Date du décès ous du jugement d'envoi en possession, en cas d'absence": "",
#             "Noms, Prénoms et demeures des parties déclarantes": "Monseu Charles",
#             "Droits de succession en ligne collatérale et de mutation en ligne directe": {
#                 "Actif. (2)": "2299",
#                 "Passif. (2)": "2299",
#                 "Restant NET. (2)": "0"
#             },
#             "Droit de mutation par décès": {
#                 "Valeur des immeubles. (2)": "2299"
#             },
#             "Numéros des déclarations": {
#                 "Primitives.": "",
#                 "Supplémentaires.": ""
#             },
#             "Date": {
#                 "de l'expiration du délai de rectification": "",
#                 "de l'exigibilité des droits": ""
#             },
#             "Numéros de la consignation des droits au sommier n' 28": "",
#             "Recette des droits et amendes": {
#                 "Date": "",
#                 "N^03": ""
#             },
#             "Cautionnements": {
#                 "Numéros de la consignation au sommier n'30": ""
#             },
#             "Observations": "",
#             "Note": "Arrêté le 10 7bre 1897 servais"
#         },
#         {
#             "N' d'ordre": "6",
#             "Date du dépot des déclarations": "1897 8bre",
#             "Désignation des personnes décédées ou absentes": {
#                 "Nom": "Bouly",
#                 "Prénoms": "Jean",
#                 "Domiciles": "Nivelles"
#             },
#             "Date du décès ous du jugement d'envoi en possession, en cas d'absence": "",
#             "Noms, Prénoms et demeures des parties déclarantes": "Bouly Henri à autre",
#             "Droits de succession en ligne collatérale et de mutation en ligne directe": {
#                 "Actif. (2)": "2299",
#                 "Passif. (2)": "2299",
#                 "Restant NET. (2)": "0"
#             },
#             "Droit de mutation par décès": {
#                 "Valeur des immeubles. (2)": "2299"
#             },
#             "Numéros des déclarations": {
#                 "Primitives.": "",
#                 "Supplémentaires.": ""
#             },
#             "Date": {
#                 "de l'expiration du délai de rectification": "",
#                 "de l'exigibilité des droits": ""
#             },
#             "Numéros de la consignation des droits au sommier n' 28": "",
#             "Recette des droits et amendes": {
#                 "Date": "",
#                 "N^03": ""
#             },
#             "Cautionnements": {
#                 "Numéros de la consignation au sommier n'30": ""
#             },
#             "Observations": "",
#             "Note": "Arrêté le 10 7bre 1897 servais"
#         },
#         {
#             "N' d'ordre": "6",
#             "Date du dépot des déclarations": "1897 8bre",
#             "Désignation des personnes décédées ou absentes": {
#                 "Nom": "Godart",
#                 "Prénoms": "Amelie",
#                 "Domiciles": "Nivelles"
#             },
#             "Date du décès ous du jugement d'envoi en possession, en cas d'absence": "",
#             "Noms, Prénoms et demeures des parties déclarantes": "Godart Henri",
#             "Droits de succession en ligne collatérale et de mutation en ligne directe": {
#                 "Actif. (2)": "2299",
#                 "Passif. (2)": "2299",
#                 "Restant NET. (2)": "0"
#             },
#             "Droit de mutation par décès": {
#                 "Valeur des immeubles. (2)": "2299"
#             },
#             "Numéros des déclarations": {
#                 "Primitives.": "",
#                 "Supplémentaires.": ""
#             },
#             "Date": {
#                 "de l'expiration du délai de rectification": "",
#                 "de l'exigibilité des droits": ""
#             },
#             "Numéros de la consignation des droits au sommier n' 28": "",
#             "Recette des droits et amendes": {
#                 "Date": "",
#                 "N^03": ""
#             },
#             "Cautionnements": {
#                 "Numéros de la consignation au sommier n'30": ""
#             },
#             "Observations": "",
#             "Note": "Arrêté le 10 7bre 1897 servais"
#         }
#     ]
# }

# %%
def checkNames(content, website_name, base64_image):
    prompt = f"""
    Your first draft:
    {content}
    
    Website:
    {website_name}
    
    Task:
    There are some transcription errors in 'Nom', 'Prénoms', and 'Noms, Prénoms et demeures des parties déclarantes' in your first draft.
    Read these items from the image again such that the corresponding names exist in Belgium according to the website.
    When you see Arrêté le \d{2} \w+ \d{4}( \w+)? servais, add it to a new key key called 'Note'. 
    If there is no information of the deceased name but only 'Arrêté le \d{2} \w+ \d{4}( \w+)? servais', add it under an empty name.
    Make sure to read the names of the people and the location as well as the dates and the numbers correctly.
    Only update those items. 
    Do not make up information.
    
    Tips:
    The family name in 'Nom' under 'Désignation des personnes décédées ou absentes.' may equal to the family name in 'Noms, Prénoms et demeures des parties déclarantes', which contains the family and first name of the declaring parties.
    But it is most likely that their first names (Prénoms) are different. 
    If the family names in 'Nom' and 'Noms, Prénoms et demeures des parties déclarantes' are the same, 'Prénoms' should be masculine.
    'Noms, Prénoms et demeures des parties déclarantes' may end with '& autre' or '& autres'.
   
    """
    return call(prompt, max_tokens=3000, base64_image=base64_image)

# %%
checkNames = checkNames(refine_json, "https://nl.geneanet.org/genealogie/", encoded_image)

# %%
checkNames_json = checkNames.json()["choices"][0]["message"]["content"]

# %%
print(checkNames_json )
# Out:
#     {
#     "entries": [
#         {
#             "N' d'ordre": "6",
#             "Date du dépot des déclarations": "1897 8bre",
#             "Désignation des personnes décédées ou absentes.": {
#                 "Nom.": "",
#                 "Prénoms": "",
#                 "Domiciles": ""
#             },
#             "Date du décès ous du jugement d'envoi en possession, en cas d'absence.": "Arrêté le 10 7bre 1897 servais",
#             "Noms, Prénoms et demeures des parties déclarantes.": "",
#             "Droits de succession en ligne collatérale et de mutation en ligne directe.": {
#                 "Actif. (2)": "",
#                 "Passif. (2)": "",
#                 "Restant NET. (2)": ""
#             },
#             "Droit de mutation par déces": {
#                 "Valeur des immeubles. (2)": ""
#             },
#             "Numéros des déclarations": {
#                 "Primitives.": "",
#                 "Supplémentaires.": ""
#             },
#             "Date": {
#                 "de l'expiration du délai de rectification.": "",
#                 "de l'exigibilité des droits.": ""
#             },
#             "Numéros de la consignation des droits au sommier n' 28": "",
#             "Recette des droits et amendes.": {
#                 "Date": "",
#                 "N^03": ""
#             },
#             "Cautionnements. ": {
#                 "Numéros de la consignation au sommier n'30": ""
#             },
#             "Observations (les déclarations qui figurent à l'état n'413 doivent être émargées en conséquence, dans la présente colonne.)": "",
#             "Note": "Arrêté le 10 7bre 1897 servais"
#         },
#         {
#             "N' d'ordre": "6",
#             "Date du dépot des déclarations": "1897 8bre",
#             "Désignation des personnes décédées ou absentes.": {
#                 "Nom.": "Leboevent",
#                 "Prénoms": "Adolphe",
#                 "Domiciles": "Ophain"
#             },
#             "Date du décès ous du jugement d'envoi en possession, en cas d'absence.": "Arrêté le 10 7bre 1897 servais",
#             "Noms, Prénoms et demeures des parties déclarantes.": "Leboevent Henri & autre",
#             "Droits de succession en ligne collatérale et de mutation en ligne directe.": {
#                 "Actif. (2)": "",
#                 "Passif. (2)": "",
#                 "Restant NET. (2)": ""
#             },
#             "Droit de mutation par déces": {
#                 "Valeur des immeubles. (2)": ""
#             },
#             "Numéros des déclarations": {
#                 "Primitives.": "",
#                 "Supplémentaires.": ""
#             },
#             "Date": {
#                 "de l'expiration du délai de rectification.": "",
#                 "de l'exigibilité des droits.": ""
#             },
#             "Numéros de la consignation des droits au sommier n' 28": "",
#             "Recette des droits et amendes.": {
#                 "Date": "",
#                 "N^03": ""
#             },
#             "Cautionnements. ": {
#                 "Numéros de la consignation au sommier n'30": ""
#             },
#             "Observations (les déclarations qui figurent à l'état n'413 doivent être émargées en conséquence, dans la présente colonne.)": "",
#             "Note": "Arrêté le 10 7bre 1897 servais"
#         },
#         {
#             "N' d'ordre": "6",
#             "Date du dépot des déclarations": "1897 8bre",
#             "Désignation des personnes décédées ou absentes.": {
#                 "Nom.": "Lefevre",
#                 "Prénoms": "Jules",
#                 "Domiciles": "Francis"
#             },
#             "Date du décès ous du jugement d'envoi en possession, en cas d'absence.": "Arrêté le 10 7bre 1897 servais",
#             "Noms, Prénoms et demeures des parties déclarantes.": "Lefevre Marie",
#             "Droits de succession en ligne collatérale et de mutation en ligne directe.": {
#                 "Actif. (2)": "",
#                 "Passif. (2)": "",
#                 "Restant NET. (2)": ""
#             },
#             "Droit de mutation par déces": {
#                 "Valeur des immeubles. (2)": ""
#             },
#             "Numéros des déclarations": {
#                 "Primitives.": "",
#                 "Supplémentaires.": ""
#             },
#             "Date": {
#                 "de l'expiration du délai de rectification.": "",
#                 "de l'exigibilité des droits.": ""
#             },
#             "Numéros de la consignation des droits au sommier n' 28": "",
#             "Recette des droits et amendes.": {
#                 "Date": "",
#                 "N^03": ""
#             },
#             "Cautionnements. ": {
#                 "Numéros de la consignation au sommier n'30": ""
#             },
#             "Observations (les déclarations qui figurent à l'état n'413 doivent être émargées en conséquence, dans la présente colonne.)": "",
#             "Note": "Arrêté le 10 7bre 1897 servais"
#         },
#         {
#             "N' d'ordre": "6",
#             "Date du dépot des déclarations": "1897 8bre",
#             "Désignation des personnes décédées ou absentes.": {
#                 "Nom.": "",
#                 "Prénoms": "",
#                 "Domiciles": ""
#             },
#             "Date du décès ous du jugement d'envoi en possession, en cas d'absence.": "Arrêté le 10 7bre 1897 servais",
#             "Noms, Prénoms et demeures des parties déclarantes.": "",
#             "Droits de succession en ligne collatérale et de mutation en ligne directe.": {
#                 "Actif. (2)": "",
#                 "Passif. (2)": "",
#                 "Restant NET. (2)": ""
#             },
#             "Droit de mutation par déces": {
#                 "Valeur des immeubles. (2)": ""
#             },
#             "Numéros des déclarations": {
#                 "Primitives.": "",
#                 "Supplémentaires.": ""
#             },
#             "Date": {
#                 "de l'expiration du délai de rectification.": "",
#                 "de l'exigibilité des droits.": ""
#             },
#             "Numéros de la consignation des droits au sommier n' 28": "",
#             "Recette des droits et amendes.": {
#                 "Date": "",
#                 "N^03": ""
#             },
#             "Cautionnements. ": {
#                 "Numéros de la consignation au sommier n'30": ""
#             },
#             "Observations (les déclarations qui figurent à l'état n'413 doivent être émargées en conséquence, dans la présente colonne.)": "",
#             "Note": "Arrêté le 10 7bre 1897 servais"
#         },
#         {
#             "N' d'ordre": "6",
#             "Date du dépot des déclarations": "1897 8bre",
#             "Désignation des personnes décédées ou absentes.": {
#                 "Nom.": "",
#                 "Prénoms": "",
#                 "Domiciles": ""
#             },
#             "Date du décès ous du jugement d'envoi en possession, en cas d'absence.": "Arrêté le 10 7bre 1897 servais",
#             "Noms, Prénoms et demeures des parties déclarantes.": "",
#             "Droits de succession en ligne collatérale et de mutation en ligne directe.": {
#                 "Actif. (2)": "",
#                 "Passif. (2)": "",
#                 "Restant NET. (2)": ""
#             },
#             "Droit de mutation par déces": {
#                 "Valeur des immeubles. (2)": ""
#             },
#             "Numéros des déclarations": {
#                 "Primitives.": "",
#                 "Supplémentaires.": ""
#             },
#             "Date": {
#                 "de l'expiration du délai de rectification.": "",
#                 "de l'exigibilité des droits.": ""
#             },
#             "Numéros de la consignation des droits au sommier n' 28": "",
#             "Recette des droits et amendes.": {
#                 "Date": "",
#                 "N^03": ""
#             },
#             "Cautionnements. ": {
#                 "Numéros de la consignation au sommier n'30": ""
#             },
#             "Observations (les déclarations qui figurent à l'état n'413 doivent être émargées en conséquence, dans la présente colonne.)": "",
#             "Note": "Arrêté le 10 7bre 1897 servais"
#         },
#         {
#             "N' d'ordre": "6",
#             "Date du dépot des déclarations": "1897 8bre",
#             "Désignation des personnes décédées ou absentes.": {
#                 "Nom.": "Desmedt",
#                 "Prénoms": "Jeanne",
#                 "Domiciles": "Nivelles"
#             },
#             "Date du décès ous du jugement d'envoi en possession, en cas d'absence.": "Arrêté le 10 7bre 1897 servais",
#             "Noms, Prénoms et demeures des parties déclarantes.": "Desmedt Henri",
#             "Droits de succession en ligne collatérale et de mutation en ligne directe.": {
#                 "Actif. (2)": "",
#                 "Passif. (2)": "",
#                 "Restant NET. (2)": ""
#             },
#             "Droit de mutation par déces": {
#                 "Valeur des immeubles. (2)": ""
#             },
#             "Numéros des déclarations": {
#                 "Primitives.": "",
#                 "Supplémentaires.": ""
#             },
#             "Date": {
#                 "de l'expiration du délai de rectification.": "",
#                 "de l'exigibilité des droits.": ""
#             },
#             "Numéros de la consignation des droits au sommier n' 28": "",
#             "Recette des droits et amendes.": {
#                 "Date": "",
#                 "N^03": ""
#             },
#             "Cautionnements. ": {
#                 "Numéros de la consignation au sommier n'30": ""
#             },
#             "Observations (les déclarations qui figurent à l'état n'413 doivent être émargées en conséquence, dans la présente colonne.)": "",
#             "Note": "Arrêté le 10 7bre 1897 servais"
#         },
#         {
#             "N' d'ordre": "6",
#             "Date du dépot des déclarations": "1897 8bre",
#             "Désignation des personnes décédées ou absentes.": {
#                 "Nom.": "Monseu",
#                 "Prénoms": "Marie",
#                 "Domiciles": "Chastre"
#             },
#             "Date du décès ous du jugement d'envoi en possession, en cas d'absence.": "Arrêté le 10 7bre 1897 servais",
#             "Noms, Prénoms et demeures des parties déclarantes.": "Monseu Charles",
#             "Droits de succession en ligne collatérale et de mutation en ligne directe.": {
#                 "Actif. (2)": "",
#                 "Passif. (2)": "",
#                 "Restant NET. (2)": ""
#             },
#             "Droit de mutation par déces": {
#                 "Valeur des immeubles. (2)": ""
#             },
#             "Numéros des déclarations": {
#                 "Primitives.": "",
#                 "Supplémentaires.": ""
#             },
#             "Date": {
#                 "de l'expiration du délai de rectification.": "",
#                 "de l'exigibilité des droits.": ""
#             },
#             "Numéros de la consignation des droits au sommier n' 28": "",
#             "Recette des droits et amendes.": {
#                 "Date": "",
#                 "N^03": ""
#             },
#             "Cautionnements. ": {
#                 "Numéros de la consignation au sommier n'30": ""
#             },
#             "Observations (les déclarations qui figurent à l'état n'413 doivent être émargées en conséquence, dans la présente colonne.)": "",
#             "Note": "Arrêté le 10 7bre 1897 servais"
#         },
#         {
#             "N' d'ordre": "6",
#             "Date du dépot des déclarations": "1897 8bre",
#             "Désignation des personnes décédées ou absentes.": {
#                 "Nom.": "Bouly",
#                 "Prénoms": "Jean",
#                 "Domiciles": "Nivelles"
#             },
#             "Date du décès ous du jugement d'envoi en possession, en cas d'absence.": "Arrêté le 10 7bre 1897 servais",
#             "Noms, Prénoms et demeures des parties déclarantes.": "Bouly Henri & autre",
#             "Droits de succession en ligne collatérale et de mutation en ligne directe.": {
#                 "Actif. (2)": "",
#                 "Passif. (2)": "",
#                 "Restant NET. (2)": ""
#             },
#             "Droit de mutation par déces": {
#                 "Valeur des immeubles. (2)": ""
#             },
#             "Numéros des déclarations": {
#                 "Primitives.": "",
#                 "Supplémentaires.": ""
#             },
#             "Date": {
#                 "de l'expiration du délai

# %% [markdown]
# There are still some errors in 'Domiciles'.
#     Check whether 'Domiciles' in your draft in the ```json block exist in Sector_{lang} of the province data in the ```csv_1 block where Commune_{lang} is {municipality}.
#     If not, consider the sectors in the province data.
#
#     If you do not find anything that resembles the texts in the image in the province data, you can write it as you see but with an asterisk.
#
#     Update 'Domiciles' in your draft in the ```json block.
#     Do not make up for missing information.
#
#     Tips:
#     The sector name written in 'Domiciles' in the image may have similar name but not exactly the same as the sector name in the province data in ```csv block.

# %%
def checkCities(content, country, province, municipality, location_path, base64_image, language="French", lang="FR"):
    txt = pd.read_csv(location_path, sep='\t')
    province = txt[txt['Province'] == {province}].copy()

    prompt = f"""
    
    Your draft:
     ```json 
    {content}
    ```
    
    Province data:
    ```txt
    {province}
    ```
    
    Task:
    There may be errors in the information you filled in 'Domiciles' in your draft in ```json block. Refine it.
    To improve 'Domiciles' in your draft, consult Sector_{lang} in the province data in ```txt block and the image. 
    When you see Arrêté le \d{2} \w+ \d{4}( \w+)? servais, add it to a new key key called 'Note'. 
    If there is no information of the deceased name but only 'Arrêté le \d{2} \w+ \d{4}( \w+)? servais', add it under an empty name.
    Make sure to read the names of the people and the location as well as the dates and the numbers correctly.
    
    Tips:
    The sector names in your draft and the province data may slightly differ.
    'Domiciles' in your draft should contain sector names in Sector_{lang}.

    
    """
    return call(prompt, max_tokens=3000, base64_image=base64_image)

# %%
location_path = os.path.join(path,'data_rag/BE_location_full.txt')

checkCities = checkCities(content = checkNames, country = "Belgium", province = "Brabant wallon", 
                          municipality = "Nivelles", location_path = location_path, 
                          base64_image = encoded_image, 
                          language = "French", lang="FR")

# %%
checkCities_json = checkCities.json()["choices"][0]["message"]["content"]

# %%
print(checkCities_json)
# Out:
#     {
#       "Response": "[200]",
#       "Domiciles": [
#         {
#           "Name": "Leboeuf",
#           "Date of Decree": "1897",
#           "Sector_FR": "Herve",
#           "Note": "Arrêté le vingt-neuf octobre 1897 servais"
#         },
#         {
#           "Name": "Lefevre",
#           "Date of Decree": "1897",
#           "Sector_FR": "Herve",
#           "Note": "Arrêté le vingt-neuf octobre 1897 servais"
#         },
#         {
#           "Name": "Desmet",
#           "Date of Decree": "1897",
#           "Sector_FR": "Bruxelles",
#           "Note": "Arrêté le deux novembre 1897 servais"
#         },
#         {
#           "Name": "Monseu",
#           "Date of Decree": "1897",
#           "Sector_FR": "Bruxelles",
#           "Note": "Arrêté le deux novembre 1897 servais"
#         },
#         {
#           "Name": "Bouly",
#           "Date of Decree": "1897",
#           "Sector_FR": "Bruxelles",
#           "Note": "Arrêté le deux novembre 1897 servais"
#         },
#         {
#           "Name": "Godart",
#           "Date of Decree": "1897",
#           "Sector_FR": "Bruxelles",
#           "Note": "Arrêté le deux novembre 1897 servais"
#         }
#       ]
#     }

# %% [markdown]
# 😢 Having troubles with the domiciles & numbers

# %% [markdown]
# # Try with iteration & examples
